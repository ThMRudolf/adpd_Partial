# %% [markdown]
# # Limpieza

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('muestra_basicos_todos.csv', header=None)

# %%
df
# Out:
#                                         0   \
# 0                                   ACEITE
# 1                ACONDICIONADOR Y ENJUAGUE
# 2                             AGUA CON GAS
# 3                             AGUA SIN GAS
# 4                             AGUA SIN GAS
# ...                                    ...
# 6995                              REFRESCO
# 6996  ROPA INTERIOR DESECHABLE Y SIMILARES
# 6997  ROPA INTERIOR DESECHABLE Y SIMILARES
# 6998                             SALCHICHA
# 6999                          SALSA CATSUP
#
#                                                      1                  2   \
# 0                                   BOTELLA 1 LT. MIXTO              1-2-3
# 1                         BOTELLA 400 ML. CONTROL CAIDA            PANTENE
# 2                                         BOTELLA 2 LT.           PEÑAFIEL
# 3                                 BOTELLA 1.5 LT. LIMON           BE-LIGHT
# 4                                       BOTELLA 1.5 LT.           BONAFONT
# ...                                                 ...                ...
# 6995                                    BOTELLA 600 ML.      SIDRAL MUNDET
# 6996  PAQUETE 10 PIEZAS. PANTS. MUJER. MEDIANO. PAÑA...               TENA
# 6997  PAQUETE 8 PIEZAS. EXTRA NOCTURNA. TOALLA PARA ...  TENA LADY DISCRET
# 6998                            PAQUETE 500 GR. DE PAVO         SAN RAFAEL
# 6999                           BOTELLA 397 GR. PLASTICO              HEINZ
#
#                                      3        4      5           6   \
# 0     ACEITES Y GRASAS VEG. COMESTIBLES  BASICOS   28.5  2018-01-02
# 1        ARTS. PARA EL CUIDADO PERSONAL  BASICOS   57.0  2018-01-02
# 2                   REFRESCOS ENVASADOS  BASICOS   21.0  2018-01-02
# 3                   REFRESCOS ENVASADOS  BASICOS   16.0  2018-01-02
# 4                   REFRESCOS ENVASADOS  BASICOS   16.5  2018-01-02
# ...                                 ...      ...    ...         ...
# 6995                REFRESCOS ENVASADOS  BASICOS   17.5  2024-01-03
# 6996  ARTS. DE PAPEL P/HIGIENE PERSONAL  BASICOS  182.5  2024-01-03
# 6997  ARTS. DE PAPEL P/HIGIENE PERSONAL  BASICOS   69.0  2024-01-03
# 6998     CARNES FRIAS SECAS Y EMBUTIDOS  BASICOS   57.0  2024-01-03
# 6999                        CONDIMENTOS  BASICOS   25.0  2024-01-03
#
#                         7          8   \
# 0                BENAVIDES  FARMACIAS
# 1                BENAVIDES  FARMACIAS
# 2                BENAVIDES  FARMACIAS
# 3                BENAVIDES  FARMACIAS
# 4                BENAVIDES  FARMACIAS
# ...                    ...        ...
# 6995  FARMACIA GUADALAJARA  FARMACIAS
# 6996  FARMACIA GUADALAJARA  FARMACIAS
# 6997  FARMACIA GUADALAJARA  FARMACIAS
# 6998  FARMACIA GUADALAJARA  FARMACIAS
# 6999  FARMACIA GUADALAJARA  FARMACIAS
#
#                                                     9   \
# 0     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 1     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 2     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 3     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 4     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# ...                                                ...
# 6995           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6996           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6997           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6998           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6999           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
#
#                                                      10              11  \
# 0     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 1     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 2     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 3     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 4     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# ...                                                 ...             ...
# 6995  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6996  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6997  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6998  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6999  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
#
#                   12         13          14
# 0     AGUASCALIENTES  21.895229 -102.311384
# 1     AGUASCALIENTES  21.895229 -102.311384
# 2     AGUASCALIENTES  21.895229 -102.311384
# 3     AGUASCALIENTES  21.895229 -102.311384
# 4     AGUASCALIENTES  21.895229 -102.311384
# ...              ...        ...         ...
# 6995  AGUASCALIENTES  21.876563 -102.318612
# 6996  AGUASCALIENTES  21.876563 -102.318612
# 6997  AGUASCALIENTES  21.876563 -102.318612
# 6998  AGUASCALIENTES  21.876563 -102.318612
# 6999  AGUASCALIENTES  21.876563 -102.318612
#
# [7000 rows x 15 columns]

# %%
df.columns = [
    "producto", "presentacion", "marca", "tipo",
    "catalogo", "precio?", "fecha", "tienda", "tipo_tienda", "sucursal", "direccion",
    "estado", "ciudad", "desconocido1", "desconocido2"
]

# %%
df
# Out:
#                                   producto  \
# 0                                   ACEITE
# 1                ACONDICIONADOR Y ENJUAGUE
# 2                             AGUA CON GAS
# 3                             AGUA SIN GAS
# 4                             AGUA SIN GAS
# ...                                    ...
# 6995                              REFRESCO
# 6996  ROPA INTERIOR DESECHABLE Y SIMILARES
# 6997  ROPA INTERIOR DESECHABLE Y SIMILARES
# 6998                             SALCHICHA
# 6999                          SALSA CATSUP
#
#                                            presentacion              marca  \
# 0                                   BOTELLA 1 LT. MIXTO              1-2-3
# 1                         BOTELLA 400 ML. CONTROL CAIDA            PANTENE
# 2                                         BOTELLA 2 LT.           PEÑAFIEL
# 3                                 BOTELLA 1.5 LT. LIMON           BE-LIGHT
# 4                                       BOTELLA 1.5 LT.           BONAFONT
# ...                                                 ...                ...
# 6995                                    BOTELLA 600 ML.      SIDRAL MUNDET
# 6996  PAQUETE 10 PIEZAS. PANTS. MUJER. MEDIANO. PAÑA...               TENA
# 6997  PAQUETE 8 PIEZAS. EXTRA NOCTURNA. TOALLA PARA ...  TENA LADY DISCRET
# 6998                            PAQUETE 500 GR. DE PAVO         SAN RAFAEL
# 6999                           BOTELLA 397 GR. PLASTICO              HEINZ
#
#                                    tipo catalogo  precio?       fecha  \
# 0     ACEITES Y GRASAS VEG. COMESTIBLES  BASICOS     28.5  2018-01-02
# 1        ARTS. PARA EL CUIDADO PERSONAL  BASICOS     57.0  2018-01-02
# 2                   REFRESCOS ENVASADOS  BASICOS     21.0  2018-01-02
# 3                   REFRESCOS ENVASADOS  BASICOS     16.0  2018-01-02
# 4                   REFRESCOS ENVASADOS  BASICOS     16.5  2018-01-02
# ...                                 ...      ...      ...         ...
# 6995                REFRESCOS ENVASADOS  BASICOS     17.5  2024-01-03
# 6996  ARTS. DE PAPEL P/HIGIENE PERSONAL  BASICOS    182.5  2024-01-03
# 6997  ARTS. DE PAPEL P/HIGIENE PERSONAL  BASICOS     69.0  2024-01-03
# 6998     CARNES FRIAS SECAS Y EMBUTIDOS  BASICOS     57.0  2024-01-03
# 6999                        CONDIMENTOS  BASICOS     25.0  2024-01-03
#
#                     tienda tipo_tienda  \
# 0                BENAVIDES   FARMACIAS
# 1                BENAVIDES   FARMACIAS
# 2                BENAVIDES   FARMACIAS
# 3                BENAVIDES   FARMACIAS
# 4                BENAVIDES   FARMACIAS
# ...                    ...         ...
# 6995  FARMACIA GUADALAJARA   FARMACIAS
# 6996  FARMACIA GUADALAJARA   FARMACIAS
# 6997  FARMACIA GUADALAJARA   FARMACIAS
# 6998  FARMACIA GUADALAJARA   FARMACIAS
# 6999  FARMACIA GUADALAJARA   FARMACIAS
#
#                                               sucursal  \
# 0     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 1     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 2     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 3     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 4     FARMACIA BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# ...                                                ...
# 6995           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6996           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6997           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6998           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
# 6999           FARMACIA GUADALAJARA SUCURSAL DEL VALLE
#
#                                               direccion          estado  \
# 0     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 1     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 2     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 3     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# 4     CONVENCION 710, ESQ. FUNDICION, COL. OLIVARES ...  AGUASCALIENTES
# ...                                                 ...             ...
# 6995  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6996  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6997  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6998  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
# 6999  AGUASCALIENTES PTE. 908, ESQ. DINAMARCA, COL. ...  AGUASCALIENTES
#
#               ciudad  desconocido1  desconocido2
# 0     AGUASCALIENTES     21.895229   -102.311384
# 1     AGUASCALIENTES     21.895229   -102.311384
# 2     AGUASCALIENTES     21.895229   -102.311384
# 3     AGUASCALIENTES     21.895229   -102.311384
# 4     AGUASCALIENTES     21.895229   -102.311384
# ...              ...           ...           ...
# 6995  AGUASCALIENTES     21.876563   -102.318612
# 6996  AGUASCALIENTES     21.876563   -102.318612
# 6997  AGUASCALIENTES     21.876563   -102.318612
# 6998  AGUASCALIENTES     21.876563   -102.318612
# 6999  AGUASCALIENTES     21.876563   -102.318612
#
# [7000 rows x 15 columns]

# %%
df["desconocido1"].unique()
# Out:
# array([21.895229, 21.895718, 21.886051, 21.876563, 21.89275 , 21.897437,
#        21.898199, 21.924925, 21.854349, 21.873323, 21.872436, 32.526358,
#        32.527136, 32.508604, 32.52737 , 32.533077, 32.529351, 32.523947,
#        32.516608, 32.532358, 24.053961, 21.916001, 21.880475, 21.875432,
#        21.880156, 21.88308 , 21.88586 , 21.874212, 21.881533, 21.922922])
