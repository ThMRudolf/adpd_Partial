# %% [markdown]
# # Limpieza de datos 'Quien es quien' en los precios PROFECO

# %% [markdown]
# En este notebook vamos a limpiar datos de una serie de archivos CSV y los vamos a guardar en archivos Parquet, particionados por catálogo y año. Los datos crudos se encuentran en carpetas de S3.
#
# Los datos originales no tienen encabezados, por lo que los añadimos manualmente.
#
# Para facilitar el trabajo, y la detección de errores, bajamos cada conjunto de datos en un dataframe por año, y hacemos las operaciones de limpieza y transformación en cada uno de los dataframes.

# %%
# %%info
# Out:
# UsageError: Cell magic `%%info` not found.

# %% [markdown]
# ## Configuramos el entorno de SPARK

# %%
# %%configure -f
# { "conf":{
#           "spark.pyspark.python": "python",
#           "spark.pyspark.virtualenv.enabled": "true",
#           "spark.pyspark.virtualenv.type":"native",
#           "spark.pyspark.virtualenv.bin.path":"/usr/bin/virtualenv"
#          }
# }
# Out:
# UsageError: Cell magic `%%configure` not found.

# %%
# Spark
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.window import Window

# Tipos de datos
from pyspark.sql.types import (
    StringType, FloatType, IntegerType, DateType, StructType, StructField
)

# Funciones de PySpark
from pyspark.sql.functions import (
    col, lit, lower, trim, regexp_replace, udf
)

# Otros
import unicodedata
from functools import reduce
import re
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>application_1746307366755_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-41-42.ec2.internal:20888/proxy/application_1746307366755_0001/">Link</a></td><td><a target="_blank" href="http://ip-172-31-32-147.ec2.internal:8042/node/containerlogs/container_1746307366755_0001_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
spark = SparkSession.builder \
    .appName("profeco_completo") \
    .getOrCreate()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Ruta base
ruta_base = "s3://itam-analytics-sofia/profeco/raw_descomprimidos"

# Lista de años
anios = list(range(2018, 2025))

# Columnas del dataset
columnas = [
    "producto", "presentacion", "marca", "tipo", "catalogo",
    "precio", "fecha", "tienda", "tipo_tienda", "sucursal",
    "direccion", "estado", "ciudad", "latitud", "longitud"
]

# Crear variables df_2018, df_2019, etc.
for anio in anios:
    ruta = f"{ruta_base}/{anio}/*.csv"
    #Leemos los CSV de cada año, y lo guardamos en un dataframe temporal
    df_tmp = spark.read.csv(ruta, header=False, inferSchema=False)
    df_tmp = df_tmp.toDF(*columnas)
    
    # Cast de tipos
    df_tmp = df_tmp.withColumn("precio", col("precio").cast(FloatType()))
    df_tmp = df_tmp.withColumn("latitud", col("latitud").cast(FloatType()))
    df_tmp = df_tmp.withColumn("longitud", col("longitud").cast(FloatType()))
    df_tmp = df_tmp.withColumn("fecha", col("fecha").cast(DateType()))
    
    # Añadir columna de AÑO
    df_tmp = df_tmp.withColumn("anio", lit(anio))
    
    # Asignar nombre a la variable globalmente (df_2018, df_2019, ...)
    globals()[f"df_{anio}"] = df_tmp
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Verifica que las variables df_2018, df_2019, ..., df_2024 existan
for anio in range(2018, 2025):
    print(f"df_{anio} existe:", f"df_{anio}" in globals())
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# df_2018 existe: True
# df_2019 existe: True
# df_2020 existe: True
# df_2021 existe: True
# df_2022 existe: True
# df_2023 existe: True
# df_2024 existe: True

# %%
for anio in range(2018, 2025):
    print(f"\n--- Esquema de df_{anio} ---")
    globals()[f"df_{anio}"].printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# --- Esquema de df_2018 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
#
# --- Esquema de df_2019 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
#
# --- Esquema de df_2020 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
#
# --- Esquema de df_2021 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
#
# --- Esquema de df_2022 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
#
# --- Esquema de df_2023 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
#
# --- Esquema de df_2024 ---
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)

# %%
for anio in range(2018, 2025):
    print(f"\n--- Datos de df_{anio} ---")
    globals()[f"df_{anio}"].show(5, truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# --- Datos de df_2018 ---
# +---------+--------------------------------------------------------------------------+--------------+-------------------+-----------------+------+----------+---------+----------------------+---------------------------------+------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# |producto |presentacion                                                              |marca         |tipo               |catalogo         |precio|fecha     |tienda   |tipo_tienda           |sucursal                         |direccion                                                         |estado        |ciudad        |latitud |longitud  |anio|
# +---------+--------------------------------------------------------------------------+--------------+-------------------+-----------------+------+----------+---------+----------------------+---------------------------------+------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# |BATIDORAS|59765. DE INMERSION. 2 VELOCIDADES. SIN TAZON                             |HAMILTON BEACH|APARATOS ELECTRICOS|ELECTRODOMESTICOS|899.0 |2018-07-09|LIVERPOOL|TIENDA DEPARTAMENTALES|LIVERPOOL SUCURSAL AGUASCALIENTES|ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES DE ALONSO, CP. 20200|AGUASCALIENTES|AGUASCALIENTES|21.92427|-102.28972|2018|
# |BATIDORAS|62647. MANUAL. 6 VELOCIDADES. SIN TAZÓN                                   |HAMILTON BEACH|APARATOS ELECTRICOS|ELECTRODOMESTICOS|799.0 |2018-07-09|LIVERPOOL|TIENDA DEPARTAMENTALES|LIVERPOOL SUCURSAL AGUASCALIENTES|ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES DE ALONSO, CP. 20200|AGUASCALIENTES|AGUASCALIENTES|21.92427|-102.28972|2018|
# |BATIDORAS|2532 Ó 2532-013. MANUAL. 6 VELOCIDADES. SIN TAZON                         |OSTER         |APARATOS ELECTRICOS|ELECTRODOMESTICOS|699.0 |2018-07-09|LIVERPOOL|TIENDA DEPARTAMENTALES|LIVERPOOL SUCURSAL AGUASCALIENTES|ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES DE ALONSO, CP. 20200|AGUASCALIENTES|AGUASCALIENTES|21.92427|-102.28972|2018|
# |BATIDORAS|FPSTHB2610W O FPSTHB2610W-013. DE INMERSIÓN. 1 VELOCIDAD. SIN TAZÓN       |OSTER         |APARATOS ELECTRICOS|ELECTRODOMESTICOS|569.0 |2018-07-09|LIVERPOOL|TIENDA DEPARTAMENTALES|LIVERPOOL SUCURSAL AGUASCALIENTES|ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES DE ALONSO, CP. 20200|AGUASCALIENTES|AGUASCALIENTES|21.92427|-102.28972|2018|
# |BATIDORAS|FPSTHB2615R O FPSTHB2615R-013. DE INMERSIÓN. VELOCIDAD VARIABLE. SIN TAZÓN|OSTER         |APARATOS ELECTRICOS|ELECTRODOMESTICOS|949.0 |2018-07-09|LIVERPOOL|TIENDA DEPARTAMENTALES|LIVERPOOL SUCURSAL AGUASCALIENTES|ZACATECAS NTE. 851, ESQ. ALTARIA, COL. TROJES DE ALONSO, CP. 20200|AGUASCALIENTES|AGUASCALIENTES|21.92427|-102.28972|2018|
# +---------+--------------------------------------------------------------------------+--------------+-------------------+-----------------+------+----------+---------+----------------------+---------------------------------+------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# only showing top 5 rows
#
#
# --- Datos de df_2019 ---
# +------------------+--------------------------------------------------------------+---------+---------------------+-----------------+------+----------+-------+---------------------------+-----------------------------+----------------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |producto          |presentacion                                                  |marca    |tipo                 |catalogo         |precio|fecha     |tienda |tipo_tienda                |sucursal                     |direccion                                                                               |estado        |ciudad        |latitud|longitud  |anio|
# +------------------+--------------------------------------------------------------+---------+---------------------+-----------------+------+----------+-------+---------------------------+-----------------------------+----------------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |BARRA DE SONIDO   |SJ2. BLUETOOTH, USB. POTENCIA 120 W. SONIDO 2.1               |LG       |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|2799.0|2019-01-21|ELEKTRA|TIENDA DE ELECTRODOMÉSTICOS|ELEKTRA SUCURSAL VILLASUNCION|MAHATMA GANDHI S/N, INTERIOR CENTRO COMERCIAL VILLASUNCION, COL. PILAR BLANCO, CP. 20289|AGUASCALIENTES|AGUASCALIENTES|21.8498|-102.29378|2019|
# |BOCINAS PORTÁTILES|SC-CMAX 1. USB Y BLUETOOTH. POTENCIA 2200 W (PMPO)            |PANASONIC|APARATOS ELECTRONICOS|ELECTRODOMESTICOS|1999.0|2019-01-21|ELEKTRA|TIENDA DE ELECTRODOMÉSTICOS|ELEKTRA SUCURSAL VILLASUNCION|MAHATMA GANDHI S/N, INTERIOR CENTRO COMERCIAL VILLASUNCION, COL. PILAR BLANCO, CP. 20289|AGUASCALIENTES|AGUASCALIENTES|21.8498|-102.29378|2019|
# |BOCINAS PORTÁTILES|MHC-V11. CD'S 1, MP3, DVD, USB Y BLUETOOTH. POTENCIA 470 W RMS|SONY     |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|3999.0|2019-01-21|ELEKTRA|TIENDA DE ELECTRODOMÉSTICOS|ELEKTRA SUCURSAL VILLASUNCION|MAHATMA GANDHI S/N, INTERIOR CENTRO COMERCIAL VILLASUNCION, COL. PILAR BLANCO, CP. 20289|AGUASCALIENTES|AGUASCALIENTES|21.8498|-102.29378|2019|
# |CAFETERAS         |BVSTDC4401RD O BVSTDC4401RD-013. CAPACIDAD 12 TAZAS           |OSTER    |APARATOS ELECTRICOS  |ELECTRODOMESTICOS|1149.0|2019-01-21|ELEKTRA|TIENDA DE ELECTRODOMÉSTICOS|ELEKTRA SUCURSAL VILLASUNCION|MAHATMA GANDHI S/N, INTERIOR CENTRO COMERCIAL VILLASUNCION, COL. PILAR BLANCO, CP. 20289|AGUASCALIENTES|AGUASCALIENTES|21.8498|-102.29378|2019|
# |CAFETERAS         |BVSTDCMVX23 Ó BVSTDCMVX23-013. CAPACIDAD 12 TAZAS             |OSTER    |APARATOS ELECTRICOS  |ELECTRODOMESTICOS|799.0 |2019-01-21|ELEKTRA|TIENDA DE ELECTRODOMÉSTICOS|ELEKTRA SUCURSAL VILLASUNCION|MAHATMA GANDHI S/N, INTERIOR CENTRO COMERCIAL VILLASUNCION, COL. PILAR BLANCO, CP. 20289|AGUASCALIENTES|AGUASCALIENTES|21.8498|-102.29378|2019|
# +------------------+--------------------------------------------------------------+---------+---------------------+-----------------+------+----------+-------+---------------------------+-----------------------------+----------------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# only showing top 5 rows
#
#
# --- Datos de df_2020 ---
# +--------+---------------------------------------------+---------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |producto|presentacion                                 |marca    |tipo                             |catalogo    |precio|fecha     |tienda      |tipo_tienda                          |sucursal                            |direccion                                                                        |estado        |ciudad        |latitud|longitud  |anio|
# +--------+---------------------------------------------+---------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |A.S.COR |FRASCO GOTERO 24 ML. 1.000 G., SOLUCION GOTAS|S/M      |MEDICAMENTOS                     |MEDICAMENTOS|253.0 |2020-02-17|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2020|
# |ACEITE  |BOTELLA 840 ML. CANOLA                       |CAPULLO  |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |27.25 |2020-02-17|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2020|
# |ACEITE  |BOTELLA 946 ML. MAIZ                         |LA GLORIA|ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |39.5  |2020-02-17|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2020|
# |ACEITE  |BOTELLA 900 ML. MAIZ                         |MAZOLA   |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |32.0  |2020-02-17|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2020|
# |ACEITE  |BOTELLA 946 ML. SOYA                         |NUTRIOLI |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |24.5  |2020-02-17|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2020|
# +--------+---------------------------------------------+---------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# only showing top 5 rows
#
#
# --- Datos de df_2021 ---
# +---------------+----------------------------+------------------+----------------------------------+--------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |producto       |presentacion                |marca             |tipo                              |catalogo|precio|fecha     |tienda      |tipo_tienda                          |sucursal                            |direccion                                                                        |estado        |ciudad        |latitud|longitud  |anio|
# +---------------+----------------------------+------------------+----------------------------------+--------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |ACEITE         |BOTELLA 1 LT. MIXTO         |1-2-3             |ACEITES Y GRASAS VEG. COMESTIBLES |BASICOS |40.9  |2021-08-09|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2021|
# |ACEITE         |BOTELLA 840 ML. CANOLA      |CAPULLO           |ACEITES Y GRASAS VEG. COMESTIBLES |BASICOS |58.5  |2021-08-09|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2021|
# |ACEITE         |BOTELLA 946 ML. CARTAMO     |OLEICO            |ACEITES Y GRASAS VEG. COMESTIBLES |BASICOS |62.8  |2021-08-09|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2021|
# |ACEITE DE OLIVA|BOTELLA 750 ML. EXTRA VIRGEN|CARBONELL         |PRODUCTOS DE TEMPORADA (NAVIDEÑOS)|BASICOS |136.0 |2021-08-09|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2021|
# |ACEITE DE OLIVA|LATA 950 ML.                |CARBONELL. CLÁSICO|PRODUCTOS DE TEMPORADA (NAVIDEÑOS)|BASICOS |179.0 |2021-08-09|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2021|
# +---------------+----------------------------+------------------+----------------------------------+--------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# only showing top 5 rows
#
#
# --- Datos de df_2022 ---
# +--------+---------------------------------------------+-------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |producto|presentacion                                 |marca  |tipo                             |catalogo    |precio|fecha     |tienda      |tipo_tienda                          |sucursal                            |direccion                                                                        |estado        |ciudad        |latitud|longitud  |anio|
# +--------+---------------------------------------------+-------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |A.S.COR |FRASCO GOTERO 24 ML. 1.000 G., SOLUCION GOTAS|S/M    |MEDICAMENTOS                     |MEDICAMENTOS|365.0 |2022-08-15|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2022|
# |ACEITE  |BOTELLA 1 LT. MIXTO                          |1-2-3  |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |52.5  |2022-08-15|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2022|
# |ACEITE  |BOTELLA 850 ML. VEGETAL                      |AVE    |ACEITES Y GRASAS VEG. COMESTIBLES|PACIC       |36.9  |2022-08-15|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2022|
# |ACEITE  |BOTELLA 946 ML. CANOLA                       |CANOIL |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |47.0  |2022-08-15|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2022|
# |ACEITE  |BOTELLA 840 ML. CANOLA                       |CAPULLO|ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |75.0  |2022-08-15|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2022|
# +--------+---------------------------------------------+-------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# only showing top 5 rows
#
#
# --- Datos de df_2023 ---
# +--------+---------------------------------------------+-------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |producto|presentacion                                 |marca  |tipo                             |catalogo    |precio|fecha     |tienda      |tipo_tienda                          |sucursal                            |direccion                                                                        |estado        |ciudad        |latitud|longitud  |anio|
# +--------+---------------------------------------------+-------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# |A.S.COR |FRASCO GOTERO 24 ML. 1.000 G., SOLUCION GOTAS|S/M    |MEDICAMENTOS                     |MEDICAMENTOS|389.0 |2023-01-02|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2023|
# |ACEITE  |BOTELLA 1 LT. VEGETAL                        |1-2-3  |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |56.0  |2023-01-02|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2023|
# |ACEITE  |BOTELLA 850 ML. VEGETAL                      |AVE    |ACEITES Y GRASAS VEG. COMESTIBLES|PACIC       |39.0  |2023-01-02|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2023|
# |ACEITE  |BOTELLA 946 ML. CANOLA                       |CANOIL |ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |50.9  |2023-01-02|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2023|
# |ACEITE  |BOTELLA 840 ML. CANOLA                       |CAPULLO|ACEITES Y GRASAS VEG. COMESTIBLES|BASICOS     |73.9  |2023-01-02|MEGA SORIANA|SUPERMERCADO / TIENDA DE AUTOSERVICIO|MEGA SORIANA SUCURSAL AGUASCALIENTES|AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116|AGUASCALIENTES|AGUASCALIENTES|21.916 |-102.29078|2023|
# +--------+---------------------------------------------+-------+---------------------------------+------------+------+----------+------------+-------------------------------------+------------------------------------+---------------------------------------------------------------------------------+--------------+--------------+-------+----------+----+
# only showing top 5 rows
#
#
# --- Datos de df_2024 ---
# +---------------+-------------------------------------------------------------+----------------------------------------+---------------------+-----------------+------+----------+------+---------------------------+--------------------------------------+------------------------------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# |producto       |presentacion                                                 |marca                                   |tipo                 |catalogo         |precio|fecha     |tienda|tipo_tienda                |sucursal                              |direccion                                                                                 |estado        |ciudad        |latitud |longitud  |anio|
# +---------------+-------------------------------------------------------------+----------------------------------------+---------------------+-----------------+------+----------+------+---------------------------+--------------------------------------+------------------------------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# |ASPIRADORAS    |HV-120 KG3 A. POTENCIA 400 WATTS                             |KOBLENZ. ASPIRADORA MANUAL DE ALTO PODER|APARATOS ELECTRICOS  |ELECTRODOMESTICOS|899.0 |2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# |BARRA DE SONIDO|S40 Q. BLUETOOTH, USB. POTENCIA 300 W. SONIDO 2.1            |LG                                      |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|4299.0|2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# |BARRA DE SONIDO|HT-S20R. BLUETOOTH, USB. POTENCIA 400 W. SONIDO 5.1          |SONY                                    |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|4499.0|2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# |BARRA DE SONIDO|S-400 O HT-S400. BLUETOOTH. USB. POTENCIA 330 W. SONIDO 2.1  |SONY                                    |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|4899.0|2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# |BATIDORAS      |FPSTHM3532 O FPSTHM3532-013. MANUAL. 6 VELOCIDADES. SIN TAZÓN|OSTER                                   |APARATOS ELECTRICOS  |ELECTRODOMESTICOS|669.0 |2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# +---------------+-------------------------------------------------------------+----------------------------------------+---------------------+-----------------+------+----------+------+---------------------------+--------------------------------------+------------------------------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# only showing top 5 rows

# %% [markdown]
# ## Limpieza de los datos:
#
# - Eliminamos las columnas que no nos interesan.
# - Estandarizamos las columnas tipo string:
#     - Convertimos a minúsculas
#     - Eliminamos acentos y caracteres especiales
#     - Eliminamos dobles espacios

# %%
columnas_a_eliminar = ['latitud', 'longitud', 'direccion', 'presentacion', 'tienda', 'tipo_tienda', 'sucursal']

df_2018_limpio = df_2018.drop(*columnas_a_eliminar)
df_2019_limpio = df_2019.drop(*columnas_a_eliminar)
df_2020_limpio = df_2020.drop(*columnas_a_eliminar)
df_2021_limpio = df_2021.drop(*columnas_a_eliminar)
df_2022_limpio = df_2022.drop(*columnas_a_eliminar)
df_2023_limpio = df_2023.drop(*columnas_a_eliminar)
df_2024_limpio = df_2024.drop(*columnas_a_eliminar)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_2024.printSchema()
df_2024.show(3, truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- tienda: string (nullable = true)
#  |-- tipo_tienda: string (nullable = true)
#  |-- sucursal: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- anio: integer (nullable = false)
#
# +---------------+---------------------------------------------------+----------------------------------------+---------------------+-----------------+------+----------+------+---------------------------+--------------------------------------+------------------------------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# |producto       |presentacion                                       |marca                                   |tipo                 |catalogo         |precio|fecha     |tienda|tipo_tienda                |sucursal                              |direccion                                                                                 |estado        |ciudad        |latitud |longitud  |anio|
# +---------------+---------------------------------------------------+----------------------------------------+---------------------+-----------------+------+----------+------+---------------------------+--------------------------------------+------------------------------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# |ASPIRADORAS    |HV-120 KG3 A. POTENCIA 400 WATTS                   |KOBLENZ. ASPIRADORA MANUAL DE ALTO PODER|APARATOS ELECTRICOS  |ELECTRODOMESTICOS|899.0 |2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# |BARRA DE SONIDO|S40 Q. BLUETOOTH, USB. POTENCIA 300 W. SONIDO 2.1  |LG                                      |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|4299.0|2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# |BARRA DE SONIDO|HT-S20R. BLUETOOTH, USB. POTENCIA 400 W. SONIDO 5.1|SONY                                    |APARATOS ELECTRONICOS|ELECTRODOMESTICOS|4499.0|2024-01-02|COPPEL|TIENDA DE ELECTRODOMÉSTICOS|COPPEL SUCURSAL ESPACIO AGUASCALIENTES|TECNOLOGICO 120, INT. CENTRO COMERCIAL ESPACIO AGUASCALIENTES, COL. OJOCALIENTE, CP. 20000|AGUASCALIENTES|AGUASCALIENTES|21.87949|-102.26001|2024|
# +---------------+---------------------------------------------------+----------------------------------------+---------------------+-----------------+------+----------+------+---------------------------+--------------------------------------+------------------------------------------------------------------------------------------+--------------+--------------+--------+----------+----+
# only showing top 3 rows

# %%
import unicodedata
from pyspark.sql.functions import udf, col
from pyspark.sql.types import StringType

# Función para limpiar texto: quitar acentos, pasar a minúsculas y eliminar dobles espacios
def limpiar_texto(texto):
    if texto is None:
        return None
    texto = unicodedata.normalize('NFKD', texto)  # Normaliza acentos
    texto = texto.encode('ASCII', 'ignore').decode('utf-8')  # Elimina acentos
    texto = texto.lower()  # Minúsculas
    texto = ' '.join(texto.split())  # Quita espacios múltiples
    return texto

# Registrar como UDF en Spark
limpiar_udf = udf(limpiar_texto, StringType())
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Columnas de texto a limpiar
columnas_texto = ['producto', 'marca', 'tipo', 'catalogo', 'estado', 'ciudad']

# Aplica la limpieza a cada DataFrame por año
for anio in range(2018, 2025):
    df = globals()[f"df_{anio}_limpio"]
    for columna in columnas_texto:
        df = df.withColumn(columna, limpiar_udf(col(columna)))
    globals()[f"df_{anio}_limpio"] = df  # actualiza el DataFrame en el entorno global
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Limpieza de columnas ESTADO y CIUDAD
#
# - Nos aseguramos que en la columna 'estado' sólo estén los nombres de los 32 estados de la República Mexicana.
# - Nos aseguramos que en la columna 'ciudad' sólo estén los nombres de ciudades Mexicanas.

# %%
for anio in range(2018, 2025):
    print(f"\n--- ESTADOS ÚNICOS en {anio} ---")
    df = globals()[f"df_{anio}_limpio"]
    estados_unicos = df.select("estado").distinct().orderBy("estado").collect()
    for fila in estados_unicos:
        print(fila["estado"])
    
    print(f"\n--- CIUDADES ÚNICAS en {anio} ---")
    ciudades_unicas = df.select("ciudad").distinct().orderBy("ciudad").collect()
    for fila in ciudades_unicas:
        print(fila["ciudad"])
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# --- ESTADOS ?NICOS en 2018 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# col. eduardo guerra
# colima
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nayarit
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2018 ---
# acapulco de juarez
# agua prieta
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# coacalco
# colima
# coyoacan
# cp. 27280"
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# ensenada
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# guasave
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# la piedad
# leon
# lerma
# los cabos
# lt. 1
# magdalena contreras
# matamoros
# mazatlan
# merida
# metepec
# mexicali
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# nogales
# nuevo laredo
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# reynosa
# rio blanco
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tapachula
# tepic
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# villa de alvarez
# xalapa
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2019 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# colima
# durango
# entre jose maria bustamante y ricardo flores magon
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nayarit
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2019 ---
# acapulco de juarez
# agua prieta
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# coacalco
# col. centro
# colima
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# ensenada
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# guasave
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# lt. 1
# magdalena contreras
# matamoros
# merida
# metepec
# mexicali
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# nogales
# nuevo laredo
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# reynosa
# rio blanco
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tapachula
# tepic
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# villa de alvarez
# xalapa
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2020 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# colima
# durango
# entre jose maria bustamante y ricardo flores magon
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nayarit
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2020 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# col. centro
# colima
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# emiliano zapata
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# guasave
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# jiutepec
# la paz
# leon
# lerma
# lt. 1
# magdalena contreras
# matamoros
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# rio blanco
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tepic
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# villa de alvarez
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2021 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# col. centro
# durango
# entre jose maria bustamante y ricardo flores magon
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2021 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# col. centro
# coyoacan
# cp. 72000"
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# lt. 1
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
#
# --- ESTADOS ?NICOS en 2022 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# col. centro
# durango
# entre jose maria bustamante y ricardo flores magon
# esq. 19 norte
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2022 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# col. centro
# col. jesus garcia
# coyoacan
# cp. 72000"
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# lt. 1
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2023 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2023 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# chilpancingo de los bravo
# ciudad madero
# coacalco
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# lt. 1
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# reynosa
# saltillo
# san luis potosi
# san nicolas de los garza
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2024 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# mz. 54
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2024 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# lt. 1
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# saltillo
# san luis potosi
# san nicolas de los garza
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
# zinacantepec

# %%
# Lista de valores inválidos
estados_invalidos = [
    "mz. 54", 
    "col. eduardo guerra", 
    "col. centro", 
    "entre jose maria bustamante y ricardo flores magon", 
    "esq. 19 norte"
]

ciudades_invalidas = [
    "lt. 1", 
    "col. centro", 
    "col. jesus garcia", 
    'cp. 27280"', 
    'cp. 72000"'
]

# Aplicar filtro a todos los DataFrames de 2018 a 2024
for anio in range(2018, 2025):
    df = globals()[f"df_{anio}_limpio"]
    
    df = df.filter(~col("estado").isin(estados_invalidos))
    df = df.filter(~col("ciudad").isin(ciudades_invalidas))
    
    globals()[f"df_{anio}_limpio"] = df
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Verificarlo

for anio in range(2018, 2025):
    df = globals()[f"df_{anio}_limpio"]
    
    print(f"\n--- ESTADOS ÚNICOS en {anio} ---")
    estados = df.select("estado").distinct().orderBy("estado").collect()
    for fila in estados:
        print(fila["estado"])
    
    print(f"\n--- CIUDADES ÚNICAS en {anio} ---")
    ciudades = df.select("ciudad").distinct().orderBy("ciudad").collect()
    for fila in ciudades:
        print(fila["ciudad"])
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# --- ESTADOS ?NICOS en 2018 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# colima
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nayarit
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2018 ---
# acapulco de juarez
# agua prieta
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# coacalco
# colima
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# ensenada
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# guasave
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# la piedad
# leon
# lerma
# los cabos
# magdalena contreras
# matamoros
# mazatlan
# merida
# metepec
# mexicali
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# nogales
# nuevo laredo
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# reynosa
# rio blanco
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tapachula
# tepic
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# villa de alvarez
# xalapa
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2019 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# colima
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nayarit
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2019 ---
# acapulco de juarez
# agua prieta
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# coacalco
# colima
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# ensenada
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# guasave
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# magdalena contreras
# matamoros
# merida
# metepec
# mexicali
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# nogales
# nuevo laredo
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# reynosa
# rio blanco
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tapachula
# tepic
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# villa de alvarez
# xalapa
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2020 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# colima
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nayarit
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2020 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# colima
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# emiliano zapata
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# guasave
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# jiutepec
# la paz
# leon
# lerma
# magdalena contreras
# matamoros
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# rio blanco
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tepic
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# villa de alvarez
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2021 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2021 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
#
# --- ESTADOS ?NICOS en 2022 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2022 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# apodaca
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# gomez palacio
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# saltillo
# san luis potosi
# san nicolas de los garza
# san pedro garza garcia
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# torreon
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2023 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2023 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# chilpancingo de los bravo
# ciudad madero
# coacalco
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# reynosa
# saltillo
# san luis potosi
# san nicolas de los garza
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
# zinacantepec
#
# --- ESTADOS ?NICOS en 2024 ---
# aguascalientes
# baja california
# baja california sur
# campeche
# chiapas
# chihuahua
# ciudad de mexico
# coahuila de zaragoza
# durango
# estado de mexico
# guanajuato
# guerrero
# hidalgo
# jalisco
# michoacan de ocampo
# morelos
# nuevo leon
# oaxaca
# puebla
# queretaro
# quintana roo
# san luis potosi
# sinaloa
# sonora
# tabasco
# tamaulipas
# tlaxcala
# veracruz
# yucatan
# zacatecas
#
# --- CIUDADES ?NICAS en 2024 ---
# acapulco de juarez
# aguascalientes
# alvaro obregon
# apizaco
# atizapan
# atizapan de zaragoza
# azcapotzalco
# benito juarez
# boca del rio
# campeche
# centro
# chihuahua
# ciudad madero
# coacalco
# coyoacan
# cuauhtemoc
# cuautitlan
# cuautitlan izcalli
# cuernavaca
# culiacan
# durango
# ecatepec
# general escobedo
# guadalajara
# guadalupe
# gustavo a. madero
# hermosillo
# huixquilucan
# iztacalco
# iztapalapa
# juarez
# la paz
# leon
# lerma
# magdalena contreras
# merida
# metepec
# miguel hidalgo
# mineral de la reforma
# monterrey
# morelia
# naucalpan
# nezahualcoyotl
# oaxaca de juarez
# orizaba
# pachuca de soto
# puebla
# saltillo
# san luis potosi
# san nicolas de los garza
# santa cruz xoxocotlan
# santa lucia del camino
# santiago de queretaro
# solidaridad
# tampico
# tijuana
# tlalnepantla
# tlalpan
# tlaquepaque
# tlaxcala
# toluca
# tonala
# tultitlan
# tuxtla gutierrez
# venustiano carranza
# veracruz
# xochimilco
# zacatecas
# zapopan
# zinacantepec

# %%
from pyspark.sql.functions import lit

#Añadir la columna "anio" a cada DataFrame
df_2018_limpio = df_2018_limpio.withColumn("anio", lit(2018))
df_2019_limpio = df_2019_limpio.withColumn("anio", lit(2019))
df_2020_limpio = df_2020_limpio.withColumn("anio", lit(2020))
df_2021_limpio = df_2021_limpio.withColumn("anio", lit(2021))
df_2022_limpio = df_2022_limpio.withColumn("anio", lit(2022))
df_2023_limpio = df_2023_limpio.withColumn("anio", lit(2023))
df_2024_limpio = df_2024_limpio.withColumn("anio", lit(2024))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ## Subir datos a S3
# - Guardamos los dataframes como uno sólo
# - Escribimos el dataframe en formato parquet particionado por año y catálogo.

# %%
df_todo = df_2018_limpio.unionByName(df_2019_limpio)\
                        .unionByName(df_2020_limpio)\
                        .unionByName(df_2021_limpio)\
                        .unionByName(df_2022_limpio)\
                        .unionByName(df_2023_limpio)\
                        .unionByName(df_2024_limpio)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_todo.write.mode("overwrite") \
    .partitionBy("catalogo", "anio") \
    .parquet("s3://itam-analytics-sofia/profeco/parquet/", compression="snappy")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#Verificamos que se haya guardado correctamente. 
df_verificacion = spark.read.parquet("s3://itam-analytics-sofia/profeco/parquet/")
df_verificacion.printSchema()
df_verificacion.select("catalogo", "anio").distinct().show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- producto: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- anio: integer (nullable = true)
#
# +-----------------+----+
# |         catalogo|anio|
# +-----------------+----+
# |          basicos|2024|
# |          basicos|2018|
# |          basicos|2020|
# |          basicos|2021|
# |          basicos|2019|
# |          basicos|2022|
# |          basicos|2023|
# |      aeropuertos|2019|
# |     medicamentos|2020|
# |     medicamentos|2024|
# |     medicamentos|2023|
# |     medicamentos|2019|
# |     medicamentos|2018|
# |     medicamentos|2021|
# |     medicamentos|2022|
# |electrodomesticos|2023|
# | utiles escolares|2019|
# | utiles escolares|2018|
# |electrodomesticos|2022|
# |electrodomesticos|2021|
# +-----------------+----+
# only showing top 20 rows
