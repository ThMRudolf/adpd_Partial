# %% [markdown]
# ## Parte A - Consultas de Spark
#
# En este notebook contestaremos a las preguntas presentadas en la Parte A utilizando consultas de Spark.
#
# Para esta parte utilizaremos los datos que hemos guardado en el notebook de *Limipieza* en formato parquet.

# %%
# %%info
# Out:
# Current session configs: <tt>{'conf': {'spark.pyspark.python': 'python', 'spark.pyspark.virtualenv.enabled': 'true', 'spark.pyspark.virtualenv.type': 'native', 'spark.pyspark.virtualenv.bin.path': '/usr/bin/virtualenv'}, 'proxyUser': 'jovyan', 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>application_1746649033970_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-88-9.ec2.internal:20888/proxy/application_1746649033970_0001/">Link</a></td><td><a target="_blank" href="http://ip-172-31-87-47.ec2.internal:8042/node/containerlogs/container_1746649033970_0001_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1</td><td>application_1746649033970_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-88-9.ec2.internal:20888/proxy/application_1746649033970_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-87-47.ec2.internal:8042/node/containerlogs/container_1746649033970_0002_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
# %%configure -f
# { "conf":{
#           "spark.pyspark.python": "python",
#           "spark.pyspark.virtualenv.enabled": "true",
#           "spark.pyspark.virtualenv.type":"native",
#           "spark.pyspark.virtualenv.bin.path":"/usr/bin/virtualenv"
#          }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2</td><td>application_1746649033970_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-88-9.ec2.internal:20888/proxy/application_1746649033970_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-87-47.ec2.internal:8042/node/containerlogs/container_1746649033970_0003_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.pyspark.python': 'python', 'spark.pyspark.virtualenv.enabled': 'true', 'spark.pyspark.virtualenv.type': 'native', 'spark.pyspark.virtualenv.bin.path': '/usr/bin/virtualenv'}, 'proxyUser': 'jovyan', 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>application_1746649033970_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-88-9.ec2.internal:20888/proxy/application_1746649033970_0001/">Link</a></td><td><a target="_blank" href="http://ip-172-31-87-47.ec2.internal:8042/node/containerlogs/container_1746649033970_0001_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>2</td><td>application_1746649033970_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-88-9.ec2.internal:20888/proxy/application_1746649033970_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-87-47.ec2.internal:8042/node/containerlogs/container_1746649033970_0003_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import col, lower, trim, regexp_replace
from pyspark.sql.window import Window
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#Abrimos sesión de Spark
spark = SparkSession.builder \
    .appName("profeco_Parte_A") \
    .getOrCreate()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# bucket
#NAME = 'thmrudolf' ##CAMBIAR AQUÍ SU NOMBRE.
NAME = 'marta'
BUCKET = f"s3://itam-analytics-{NAME}"
FOLDER = 'profeco'


# type of catalog
CATALOG_TYPE = 'basicos'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from pyspark.sql.functions import asc, desc

#Leemos los archivos de la carpeta parquet
df_parquet = spark.read.parquet(f"{BUCKET}/{FOLDER}/parquet")
df_parquet.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- producto: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- anio: integer (nullable = true)

# %% [markdown]
# ## Preguntas Generales
#
# Comenzamos constestando las preguntas generales, referidas a todos los catálogos y todos los estados.
#
# Queremos un análisis **(por año)** y sobre todos los catálogos.
#
# * ¿Cuántos catálogos diferentes tenemos?
# * ¿Cuáles son los 20 catálogos con más observaciones? Guarda la salida de este query en tu bucket de S3, lo necesitaremos más adelante.
# * ¿Tenemos datos de todos los estados del país? De no ser así, ¿cuáles faltan?
# * ¿Cuántas observaciones tenemos por estado?
# * De cada estado obten: el número de catalogos diferentes por año, ¿ha  aumentado el número de catálogos con el tiempo?

# %% [markdown]
# ### Catálogos diferentes:
# Contestaremos a las preguntas referentes a número de catálogos y catálogos con más observaciones.
#
# Para número de catálogos, veremos el total, luego número de catálogos por año, y finalmente qué catálogos se registraron en cada año.

# %%
#¿Cuántos catálogos diferentes hay?
total_catalogos = df_parquet.select("catalogo").distinct().count()
print(f"El total de catalogos distintos es: {total_catalogos}")
#Veamos cuáles son sus nombres
catalogos_name = df_parquet.select("catalogo").distinct().show()
#Nº de catálogos por año:
df_catalogo_anio = df_parquet.groupBy("anio")\
    .agg(F.countDistinct("catalogo").alias("num_catalogos"))\
    .orderBy("anio")\
    .show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# El total de catalogos distintos es: 12
# +-------------------+
# |           catalogo|
# +-------------------+
# |            basicos|
# |        aeropuertos|
# |       medicamentos|
# |  electrodomesticos|
# |   utiles escolares|
# |           juguetes|
# |           mercados|
# | frutas y legumbres|
# |              pacic|
# |          navidenos|
# |pescados y mariscos|
# |              tenis|
# +-------------------+
#
# +----+-------------+
# |anio|num_catalogos|
# +----+-------------+
# |2018|           10|
# |2019|           11|
# |2020|           10|
# |2021|           10|
# |2022|           11|
# |2023|           11|
# |2024|           10|
# +----+-------------+

# %% [markdown]
# A pesar de que el total de catálogos es 12, vemos que en ningún año se registran los 12 catálogos. Es decir en cada año, siempre faltan uno o dos catálgos sin registrar.  Vamos a ver cuáles son

# %%
#Cuales son esos catálogos
df_parquet.groupBy("anio")\
    .agg(F.collect_set("catalogo").alias("catalogos"))\
    .orderBy("anio")\
    .show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----+--------------------------------------------------------------------------------------------------------------------------------------------------------+
# |anio|catalogos                                                                                                                                               |
# +----+--------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2018|[pescados y mariscos, juguetes, utiles escolares, frutas y legumbres, navidenos, electrodomesticos, medicamentos, tenis, basicos, mercados]             |
# |2019|[pescados y mariscos, juguetes, utiles escolares, aeropuertos, frutas y legumbres, navidenos, electrodomesticos, medicamentos, tenis, basicos, mercados]|
# |2020|[pescados y mariscos, juguetes, utiles escolares, aeropuertos, frutas y legumbres, navidenos, electrodomesticos, medicamentos, basicos, mercados]       |
# |2021|[pescados y mariscos, juguetes, utiles escolares, frutas y legumbres, navidenos, electrodomesticos, medicamentos, tenis, basicos, mercados]             |
# |2022|[pescados y mariscos, juguetes, utiles escolares, frutas y legumbres, navidenos, electrodomesticos, medicamentos, tenis, pacic, basicos, mercados]      |
# |2023|[pescados y mariscos, juguetes, utiles escolares, frutas y legumbres, navidenos, electrodomesticos, medicamentos, tenis, pacic, basicos, mercados]      |
# |2024|[pescados y mariscos, juguetes, utiles escolares, frutas y legumbres, navidenos, electrodomesticos, medicamentos, pacic, basicos, mercados]             |
# +----+--------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ### Catálogos con más observaciones
#
# Vemos también de forma general, cuántas observaciones por catálogo en todos los años observados y también disgregados por año. De esta forma, observamos más rápidamente en qué año se tuvo registro de qué catálogo y cuántos registros se hicieron.

# %%
#Catálogos con más observaciones
#Totales
df_parquet.groupBy("catalogo") \
    .agg(F.count("*").alias("num_observaciones")) \
    .orderBy(desc("num_observaciones")) \
    .show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------------------+-----------------+
# |catalogo           |num_observaciones|
# +-------------------+-----------------+
# |basicos            |46967421         |
# |medicamentos       |19223453         |
# |electrodomesticos  |7175538          |
# |frutas y legumbres |5041732          |
# |utiles escolares   |2936010          |
# |mercados           |2238684          |
# |juguetes           |1432183          |
# |pacic              |1079162          |
# |pescados y mariscos|569632           |
# |navidenos          |236543           |
# |tenis              |15768            |
# |aeropuertos        |581              |
# +-------------------+-----------------+

# %%
#Observaciones por año. 
df_obs = df_parquet.groupBy("catalogo", "anio") \
    .agg(F.count("*").alias("num_observaciones")) \
    .orderBy("catalogo", "anio")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#IMPRESION CLARA
from itertools import groupby

rows = df_obs.collect()

for catalogo, grupo in groupby(rows, key=lambda r: r['catalogo']):
    print(f"\n\n{'='*60}")
    print(f"CATÁLOGO: {catalogo}")
    print(f"{'='*60}")
    print(f"{'Año':<10} {'Observaciones':>20}")
    print("-" * 35)
    for row in grupo:
        print(f"{row['anio']:<10} {row['num_observaciones']:>20}")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ============================================================
# CAT?LOGO: aeropuertos
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2019                        579
# 2020                          2
#
#
# ============================================================
# CAT?LOGO: basicos
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                    8804761
# 2019                    7398860
# 2020                    6170515
# 2021                    6919490
# 2022                    7945110
# 2023                    7742108
# 2024                    1986577
#
#
# ============================================================
# CAT?LOGO: electrodomesticos
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                    1735336
# 2019                    1352068
# 2020                     602860
# 2021                    1004833
# 2022                    1029302
# 2023                    1183304
# 2024                     267835
#
#
# ============================================================
# CAT?LOGO: frutas y legumbres
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                     938616
# 2019                     702747
# 2020                     643820
# 2021                     756850
# 2022                     926031
# 2023                     861829
# 2024                     211839
#
#
# ============================================================
# CAT?LOGO: juguetes
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                     370421
# 2019                     267730
# 2020                     181907
# 2021                     207318
# 2022                     180332
# 2023                     205361
# 2024                      19114
#
#
# ============================================================
# CAT?LOGO: medicamentos
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                    3657969
# 2019                    2887105
# 2020                    2571915
# 2021                    2937404
# 2022                    3177815
# 2023                    3192617
# 2024                     798628
#
#
# ============================================================
# CAT?LOGO: mercados
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                     457497
# 2019                     381183
# 2020                     312800
# 2021                     318280
# 2022                     367637
# 2023                     324401
# 2024                      76886
#
#
# ============================================================
# CAT?LOGO: navidenos
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                      58674
# 2019                      42538
# 2020                      26111
# 2021                      43490
# 2022                      33365
# 2023                      32163
# 2024                        202
#
#
# ============================================================
# CAT?LOGO: pacic
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2022                     251709
# 2023                     671655
# 2024                     155798
#
#
# ============================================================
# CAT?LOGO: pescados y mariscos
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                      90040
# 2019                      69658
# 2020                      50978
# 2021                      74902
# 2022                     114753
# 2023                     123335
# 2024                      45966
#
#
# ============================================================
# CAT?LOGO: tenis
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                       4452
# 2019                       4306
# 2021                       1687
# 2022                       2249
# 2023                       3074
#
#
# ============================================================
# CAT?LOGO: utiles escolares
# ============================================================
# A?o               Observaciones
# -----------------------------------
# 2018                     665135
# 2019                     575317
# 2020                     219573
# 2021                     549740
# 2022                     421178
# 2023                     442965
# 2024                      62102

# %% [markdown]
#  ### Top 20 observaciones:
#  Para cada catálogo, obtenemos la lista de los productos con más observaciones.
#
#  Esto lo hacemos de forma global y desagregada por año.

# %%
#Top 20 productos por catálogo de forma global
from pyspark.sql import functions as F
from pyspark.sql.window import Window

#Primero hacemos la búsqueda, y la guardamos en un dataframe. 

# Paso 1: Contamos observaciones por producto y catálogo
df_producto_catalogo = df_parquet.groupBy("catalogo", "producto") \
    .agg(F.count("*").alias("num_observaciones"))

# Paso 2: Definimos ventana para rankear productos por catálogo
window_catalogo = Window.partitionBy("catalogo").orderBy(F.desc("num_observaciones"))

# Paso 3: Asignamos ranking y filtramos top 20
df_top20 = df_producto_catalogo.withColumn("rank", F.row_number().over(window_catalogo)) \
                               .filter(F.col("rank") <= 20)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#Imprimimos el resultado, de forma legible

catalogos = df_top20.select("catalogo").distinct().orderBy("catalogo").rdd.flatMap(lambda x: x).collect()

for catalogo in catalogos:
    print(f"\n\n{'='*50}")
    print(f"CATÁLOGO: {catalogo.upper()}")
    print(f"{'='*50}")
    
    df_top20.filter(F.col("catalogo") == catalogo) \
            .orderBy("rank") \
            .select("producto", "num_observaciones") \
            .show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ==================================================
# CAT?LOGO: AEROPUERTOS
# ==================================================
# +-----------------------------------+-----------------+
# |producto                           |num_observaciones|
# +-----------------------------------+-----------------+
# |refresco                           |114              |
# |pastelillos y pan dulce empaquetado|99               |
# |desodorante                        |76               |
# |agua con gas                       |30               |
# |jabon de tocador                   |29               |
# |leche ultrapasteurizada            |29               |
# |cacahuates                         |23               |
# |talco                              |18               |
# |galletas dulces                    |18               |
# |agua sin gas                       |17               |
# |sterimar                           |17               |
# |salsa picante                      |16               |
# |galletas saladas                   |16               |
# |picot. sal de uvas                 |16               |
# |lamisil                            |14               |
# |jugo de fruta                      |14               |
# |rastrillos desechables             |11               |
# |barras de cereal                   |7                |
# |toallita humeda limpiadora         |6                |
# |plantaben                          |5                |
# +-----------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: BASICOS
# ==================================================
# +-----------------------------------+-----------------+
# |producto                           |num_observaciones|
# +-----------------------------------+-----------------+
# |refresco                           |2074219          |
# |jamon                              |1305161          |
# |shampoo                            |1236419          |
# |desodorante                        |1118633          |
# |toalla femenina                    |1040613          |
# |leche ultrapasteurizada            |911970           |
# |detergente p/ropa                  |896315           |
# |jabon de tocador                   |873236           |
# |yoghurt                            |835282           |
# |salchicha                          |802097           |
# |papas fritas y similares           |794621           |
# |chiles                             |738224           |
# |carne res                          |710228           |
# |pastelillos y pan dulce empaquetado|663434           |
# |carne cerdo                        |659697           |
# |cerveza                            |652075           |
# |agua sin gas                       |615703           |
# |atun                               |610953           |
# |cafe soluble                       |585686           |
# |mayonesa                           |577843           |
# +-----------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: ELECTRODOMESTICOS
# ==================================================
# +-----------------------------------+-----------------+
# |producto                           |num_observaciones|
# +-----------------------------------+-----------------+
# |pantallas                          |796729           |
# |lavadoras                          |677928           |
# |estufas                            |593794           |
# |refrigeradores                     |579122           |
# |planchas                           |441089           |
# |horno de microondas                |347660           |
# |licuadoras                         |344379           |
# |componentes de audio               |294134           |
# |extractores de jugos y exprimidores|275579           |
# |celulares                          |263992           |
# |cafeteras                          |261716           |
# |batidoras                          |261153           |
# |bocinas portatiles                 |219757           |
# |dvd / blu ray                      |189138           |
# |horno electrico                    |175841           |
# |electronicos de video              |170949           |
# |sandwicheras                       |140171           |
# |camaras digitales                  |129034           |
# |olla de presion express            |116270           |
# |secadoras                          |110378           |
# +-----------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: FRUTAS Y LEGUMBRES
# ==================================================
# +------------+-----------------+
# |producto    |num_observaciones|
# +------------+-----------------+
# |chile fresco|394568           |
# |manzana     |273092           |
# |cebolla     |179824           |
# |platano     |177399           |
# |limon       |165295           |
# |jitomate    |161851           |
# |lechuga     |158352           |
# |col         |144517           |
# |uva         |136534           |
# |melon       |130181           |
# |mango       |117795           |
# |zanahoria   |115456           |
# |tomate      |106305           |
# |pera        |98421            |
# |papa        |96965            |
# |papaya      |95354            |
# |aguacate    |94171            |
# |pepino      |92350            |
# |naranja     |92264            |
# |calabaza    |90096            |
# +------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: JUGUETES
# ==================================================
# +-----------------------------+-----------------+
# |producto                     |num_observaciones|
# +-----------------------------+-----------------+
# |juegos de mesa               |299903           |
# |varios                       |288958           |
# |munecas                      |196275           |
# |juguetes educativos          |117267           |
# |juguetes de destreza         |110411           |
# |munecos                      |97521            |
# |juguetes armables            |67323            |
# |autopistas                   |64120            |
# |videojuegos                  |42735            |
# |munecas electricas           |37276            |
# |motos y carros mecanicos     |36963            |
# |motos y carros electricos    |26565            |
# |munecos electricos           |19456            |
# |electronicos de video        |17628            |
# |juguetes montables           |8023             |
# |juguetes montables electricos|1662             |
# |enseres domesticos           |97               |
# +-----------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: MEDICAMENTOS
# ==================================================
# +------------------------------------------+-----------------+
# |producto                                  |num_observaciones|
# +------------------------------------------+-----------------+
# |gel antibacterial                         |194601           |
# |tabcin                                    |177356           |
# |cialis                                    |164696           |
# |cubrebocas                                |162689           |
# |cafiaspirina                              |157700           |
# |celestamine-ns                            |156591           |
# |micardis                                  |147435           |
# |lyrica                                    |147279           |
# |celebrex                                  |146797           |
# |lexapro                                   |137380           |
# |alevian duo                               |127077           |
# |levitra                                   |120340           |
# |"amoxicilina"amoxicilinaacido clavulanico"|111811           |
# |dolo-neurobion forte                      |108700           |
# |tempra                                    |108617           |
# |aspirina                                  |107581           |
# |nexium-mups                               |105695           |
# |riopan                                    |105543           |
# |venda elastica                            |105044           |
# |vick vaporub                              |101534           |
# +------------------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: MERCADOS
# ==================================================
# +-----------------------------------+-----------------+
# |producto                           |num_observaciones|
# +-----------------------------------+-----------------+
# |carne cerdo                        |182037           |
# |carne res                          |168649           |
# |detergente p/ropa                  |94680            |
# |frijol                             |69489            |
# |chile seco                         |68616            |
# |chiles                             |56686            |
# |limpiador liquido p/piso           |53801            |
# |carne pollo                        |48028            |
# |blanqueador                        |44154            |
# |mayonesa                           |44008            |
# |aceite                             |43475            |
# |mole rojo en pasta                 |40048            |
# |jamon                              |38134            |
# |jabon de pasta                     |36373            |
# |salchicha                          |35623            |
# |crema                              |31096            |
# |arroz                              |30543            |
# |jabon de tocador                   |30482            |
# |polvo para bebidas sabor chocolate |29814            |
# |pastelillos y pan dulce empaquetado|29204            |
# +-----------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: NAVIDENOS
# ==================================================
# +----------------------------------+-----------------+
# |producto                          |num_observaciones|
# +----------------------------------+-----------------+
# |vino de mesa                      |133121           |
# |aceituna                          |26062            |
# |sidra                             |17655            |
# |rompope                           |14618            |
# |aceite de oliva                   |11572            |
# |jerez                             |7477             |
# |alcaparra                         |6997             |
# |pavo                              |5857             |
# |bacalao                           |5737             |
# |orejon/fruta seca                 |2306             |
# |chiles largos en escabeche        |1727             |
# |datil                             |1207             |
# |turron                            |1076             |
# |frutas cubiertas                  |428              |
# |chiles largos o gueros carricillos|371              |
# |figuras de mazapan                |260              |
# |colacion                          |38               |
# |pescado seco salado               |20               |
# |avellana                          |9                |
# |polvoron                          |5                |
# +----------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: PACIC
# ==================================================
# +-----------------------+-----------------+
# |producto               |num_observaciones|
# +-----------------------+-----------------+
# |pasta para sopa        |175915           |
# |atun                   |62293            |
# |arroz                  |46467            |
# |aceite                 |45198            |
# |papel higienico        |43959            |
# |huevo                  |42433            |
# |leche ultrapasteurizada|40987            |
# |carne cerdo            |40694            |
# |jabon de tocador       |39163            |
# |carne pollo            |39150            |
# |sardina                |38152            |
# |frijol                 |36918            |
# |tortilla de maiz       |35009            |
# |limon                  |34775            |
# |manzana                |33626            |
# |azucar                 |33262            |
# |carne res              |33065            |
# |cebolla                |32294            |
# |chile fresco           |32116            |
# |jitomate               |31542            |
# +-----------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: PESCADOS Y MARISCOS
# ==================================================
# +--------------------------------------------+-----------------+
# |producto                                    |num_observaciones|
# +--------------------------------------------+-----------------+
# |mojarra                                     |87309            |
# |camaron                                     |81789            |
# |basa                                        |44142            |
# |calamar                                     |40085            |
# |salmon                                      |31320            |
# |huachinango                                 |24531            |
# |sierra                                      |23153            |
# |pulpo                                       |22248            |
# |tilapia                                     |18783            |
# |almeja                                      |18674            |
# |atun                                        |18279            |
# |barrita de surimi o barrita de surimi cangre|16777            |
# |cazon                                       |14169            |
# |blanco del nilo                             |13504            |
# |jaiba                                       |12034            |
# |bagre                                       |10188            |
# |robalo                                      |9563             |
# |lisa                                        |8451             |
# |bandera                                     |8195             |
# |jurel                                       |7218             |
# +--------------------------------------------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: TENIS
# ==================================================
# +--------+-----------------+
# |producto|num_observaciones|
# +--------+-----------------+
# |tenis   |15768            |
# +--------+-----------------+
#
#
#
# ==================================================
# CAT?LOGO: UTILES ESCOLARES
# ==================================================
# +-----------------------+-----------------+
# |producto               |num_observaciones|
# +-----------------------+-----------------+
# |colores de madera      |383085           |
# |cuaderno profesional   |265345           |
# |crayones               |227234           |
# |lapiz                  |184417           |
# |boligrafo tinta negra  |174759           |
# |plumones               |142822           |
# |lapiz adhesivo         |127997           |
# |sacapuntas             |122805           |
# |pliegos de papel       |107051           |
# |goma borrador          |85629            |
# |pegamento              |78041            |
# |cuaderno forma francesa|72360            |
# |cinta adhesiva         |66086            |
# |juego de geometria     |65304            |
# |tijeras                |65075            |
# |calculadoras           |56144            |
# |diccionario            |51631            |
# |cuaderno forma italiana|51430            |
# |folders                |50161            |
# |portaminas             |49563            |
# +-----------------------+-----------------+

# %% [markdown]
# #### Top 20 observaciones por año y catálogo

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

#CONSULTA
# Agrupamos por año, catálogo y producto, y contamos observaciones
df_productos = df_parquet.groupBy("anio", "catalogo", "producto") \
    .agg(F.count("*").alias("num_observaciones"))

# Definimos ventana por año y catálogo, ordenando por observaciones
window_anio_catalogo = Window.partitionBy("anio", "catalogo").orderBy(F.desc("num_observaciones"))

# Asignamos ranking dentro de cada (anio, catálogo)
df_top20 = df_productos.withColumn("rank", F.row_number().over(window_anio_catalogo)) \
                       .filter(F.col("rank") <= 20) \
                       .orderBy("anio", "catalogo", "rank")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#IMPRESIÓN
# Colectamos los resultados al driver para impresión legible
rows = df_top20.select("anio", "catalogo", "producto", "num_observaciones", "rank").collect()

from itertools import groupby

# Agrupamos primero por año, luego por catálogo
for anio, grupo_anio in groupby(rows, key=lambda r: r['anio']):
    print(f"\n\n{'='*50}")
    print(f"AÑO: {anio}")
    print(f"{'='*50}")

    for catalogo, grupo_catalogo in groupby(grupo_anio, key=lambda r: r['catalogo']):
        print(f"\n\n{'='*50}")
        print(f"CATÁLOGO: {catalogo.upper()}")
        print(f"{'='*50}")
        print(f"{'Producto':<40} {'Observaciones':>15}")
        print("-" * 55)
        for row in grupo_catalogo:
            print(f"{row['producto']:<40} {row['num_observaciones']:>15}")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ==================================================
# A?O: 2018
# ==================================================
#
#
# ==================================================
# CAT?LOGO: BASICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                          354645
# shampoo                                           237287
# jamon                                             233890
# detergente p/ropa                                 209923
# jabon de tocador                                  189397
# desodorante                                       183639
# leche ultrapasteurizada                           175402
# salchicha                                         167123
# chiles                                            155833
# yoghurt                                           152508
# cerveza                                           142318
# leche en polvo                                    141010
# toalla femenina                                   139600
# mayonesa                                          135025
# carne res                                         133993
# cafe soluble                                      123248
# papas fritas y similares                          122054
# carne cerdo                                       118048
# aceite                                            117773
# crema liquida                                     111060
#
#
# ==================================================
# CAT?LOGO: ELECTRODOMESTICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# pantallas                                         217278
# refrigeradores                                    152845
# lavadoras                                         143275
# componentes de audio                              137774
# planchas                                          128393
# estufas                                           120039
# licuadoras                                         91070
# horno de microondas                                86712
# dvd / blu ray                                      79168
# extractores de jugos y exprimidores                67077
# batidoras                                          66870
# cafeteras                                          50585
# camaras digitales                                  42977
# bocinas portatiles                                 39697
# horno electrico                                    37907
# sandwicheras                                       33770
# electronicos de video                              31852
# sistemas de teatro en casa home theater            24234
# olla de presion express                            23952
# secadoras                                          23657
#
#
# ==================================================
# CAT?LOGO: FRUTAS Y LEGUMBRES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# chile fresco                                       64189
# manzana                                            42792
# cebolla                                            34769
# platano                                            33981
# lechuga                                            32251
# jitomate                                           31948
# limon                                              30910
# col                                                28198
# melon                                              27602
# mango                                              23086
# uva                                                22522
# zanahoria                                          20957
# tomate                                             19799
# pera                                               18982
# pina                                               18643
# papa                                               18392
# papaya                                             18282
# aguacate                                           18061
# pepino                                             17799
# naranja                                            17601
#
#
# ==================================================
# CAT?LOGO: JUGUETES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# varios                                             88154
# juegos de mesa                                     76521
# munecas                                            52646
# munecos                                            28787
# juguetes de destreza                               27565
# juguetes educativos                                18932
# juguetes armables                                  16324
# videojuegos                                        14655
# autopistas                                         10126
# munecas electricas                                  9351
# motos y carros mecanicos                            6862
# munecos electricos                                  6657
# motos y carros electricos                           6342
# electronicos de video                               3997
# juguetes montables                                  2828
# juguetes montables electricos                        577
# enseres domesticos                                    97
#
#
# ==================================================
# CAT?LOGO: MEDICAMENTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# cialis                                             33544
# celestamine-ns                                     32239
# micardis                                           31421
# lyrica                                             31055
# celebrex                                           30505
# levitra                                            30343
# lexapro                                            29460
# alevian duo                                        26324
# "amoxicilina"amoxicilinaacido clavulanico"           24796
# riopan                                             22031
# dolo-neurobion forte                               21771
# dolo-neurobion                                     21531
# nexium-mups                                        21519
# micardis plus                                      21480
# aspirina                                           21365
# viagra                                             20956
# fosfocil                                           20816
# crestor                                            20669
# arcoxia                                            20574
# terramicina                                        20546
#
#
# ==================================================
# CAT?LOGO: MERCADOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# carne cerdo                                        38345
# carne res                                          32521
# detergente p/ropa                                  24457
# limpiador liquido p/piso                           12931
# frijol                                             12667
# chile seco                                         12583
# mayonesa                                           11438
# mole rojo en pasta                                 11207
# jabon de pasta                                     10732
# carne pollo                                        10410
# blanqueador                                        10206
# polvo para bebidas sabor chocolate                  9498
# salchicha                                           9200
# pastelillos y pan dulce empaquetado                 7951
# aceite                                              7923
# chiles                                              7896
# galletas populares                                  7077
# elote                                               7053
# jamon                                               6784
# mostaza                                             6666
#
#
# ==================================================
# CAT?LOGO: NAVIDENOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# vino de mesa                                       34345
# aceituna                                            5838
# sidra                                               4810
# rompope                                             4309
# aceite de oliva                                     2585
# jerez                                               1831
# alcaparra                                           1416
# orejon/fruta seca                                    849
# bacalao                                              804
# pavo                                                 784
# datil                                                349
# turron                                               294
# chiles largos en escabeche                           194
# frutas cubiertas                                     125
# figuras de mazapan                                    61
# chiles largos o gueros carricillos                    54
# colacion                                              21
# polvoron                                               5
#
#
# ==================================================
# CAT?LOGO: PESCADOS Y MARISCOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# mojarra                                            14098
# camaron                                             9906
# calamar                                             8649
# salmon                                              5851
# pulpo                                               4610
# huachinango                                         4223
# sierra                                              3948
# cazon                                               3667
# almeja                                              3545
# atun                                                3368
# jaiba                                               2531
# bandera                                             2182
# lisa                                                2028
# bagre                                               2023
# robalo                                              1979
# jaibon                                              1651
# jurel                                               1492
# pargo                                               1197
# blanco del nilo                                     1161
# callo de hacha                                      1149
#
#
# ==================================================
# CAT?LOGO: TENIS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# tenis                                               4452
#
#
# ==================================================
# CAT?LOGO: UTILES ESCOLARES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# colores de madera                                  79576
# cuaderno profesional                               69214
# crayones                                           47127
# boligrafo tinta negra                              37716
# lapiz                                              37004
# pliegos de papel                                   28429
# lapiz adhesivo                                     27664
# sacapuntas                                         24932
# plumones                                           22948
# cuaderno forma francesa                            19755
# goma borrador                                      19421
# pegamento                                          16250
# tijeras                                            15567
# juego de geometria                                 13770
# cinta adhesiva                                     13413
# cuaderno forma italiana                            12696
# diccionario                                        12029
# portaminas                                         11872
# calculadoras                                       11777
# folders                                            11568
#
#
# ==================================================
# A?O: 2019
# ==================================================
#
#
# ==================================================
# CAT?LOGO: AEROPUERTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                             112
# pastelillos y pan dulce empaquetado                   99
# desodorante                                           76
# agua con gas                                          30
# jabon de tocador                                      29
# leche ultrapasteurizada                               29
# cacahuates                                            23
# galletas dulces                                       18
# talco                                                 18
# sterimar                                              17
# agua sin gas                                          17
# galletas saladas                                      16
# picot. sal de uvas                                    16
# salsa picante                                         16
# lamisil                                               14
# jugo de fruta                                         14
# rastrillos desechables                                11
# barras de cereal                                       7
# toallita humeda limpiadora                             6
# plantaben                                              5
#
#
# ==================================================
# CAT?LOGO: BASICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                          330531
# shampoo                                           204189
# jamon                                             198712
# desodorante                                       176668
# leche ultrapasteurizada                           156699
# jabon de tocador                                  148902
# papas fritas y similares                          146473
# detergente p/ropa                                 136346
# toalla femenina                                   128090
# pastelillos y pan dulce empaquetado               126453
# yoghurt                                           125222
# salchicha                                         121474
# chiles                                            113070
# carne res                                         108208
# cerveza                                           107464
# mayonesa                                          100953
# carne cerdo                                        98189
# atun                                               96675
# leche en polvo                                     95362
# cafe soluble                                       95299
#
#
# ==================================================
# CAT?LOGO: ELECTRODOMESTICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# pantallas                                         166225
# lavadoras                                         128097
# refrigeradores                                    109129
# estufas                                            92632
# planchas                                           89309
# componentes de audio                               85766
# licuadoras                                         74172
# horno de microondas                                70784
# batidoras                                          59823
# extractores de jugos y exprimidores                49497
# dvd / blu ray                                      48323
# cafeteras                                          44956
# camaras digitales                                  35452
# electronicos de video                              29556
# horno electrico                                    29438
# bocinas portatiles                                 25675
# celulares                                          25086
# olla de presion express                            23785
# sandwicheras                                       22229
# secadoras                                          21193
#
#
# ==================================================
# CAT?LOGO: FRUTAS Y LEGUMBRES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# chile fresco                                       47721
# manzana                                            30941
# cebolla                                            26054
# platano                                            25688
# jitomate                                           24321
# lechuga                                            24131
# limon                                              23723
# col                                                20944
# melon                                              20260
# uva                                                16461
# mango                                              16133
# zanahoria                                          15960
# pera                                               15253
# tomate                                             15244
# papa                                               13811
# papaya                                             13715
# aguacate                                           13505
# pepino                                             13445
# naranja                                            13426
# pina                                               13315
#
#
# ==================================================
# CAT?LOGO: JUGUETES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# juegos de mesa                                     59837
# varios                                             53289
# munecas                                            37338
# juguetes de destreza                               22101
# juguetes educativos                                19044
# munecos                                            18149
# autopistas                                         10877
# juguetes armables                                   9631
# videojuegos                                         8490
# motos y carros mecanicos                            7112
# munecas electricas                                  6694
# motos y carros electricos                           5244
# munecos electricos                                  3617
# electronicos de video                               3237
# juguetes montables                                  2446
# juguetes montables electricos                        624
#
#
# ==================================================
# CAT?LOGO: MEDICAMENTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# micardis                                           25812
# cialis                                             25649
# lyrica                                             25262
# celestamine-ns                                     25036
# lexapro                                            23681
# celebrex                                           23258
# levitra                                            21222
# alevian duo                                        20401
# "amoxicilina"amoxicilinaacido clavulanico"           19010
# riopan                                             17964
# nexium-mups                                        17645
# micardis plus                                      17435
# viagra                                             17061
# dolo-neurobion forte                               16866
# aspirina                                           16510
# terramicina                                        16500
# vick vaporub                                       16366
# fosfocil                                           16099
# lipitor                                            16022
# crestor                                            15977
#
#
# ==================================================
# CAT?LOGO: MERCADOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# carne cerdo                                        28586
# carne res                                          24036
# detergente p/ropa                                  18950
# limpiador liquido p/piso                           10373
# frijol                                             10149
# chile seco                                         10122
# chiles                                              8348
# blanqueador                                         8297
# mayonesa                                            8278
# mole rojo en pasta                                  7829
# jabon de pasta                                      7668
# salchicha                                           7244
# carne pollo                                         7052
# jamon                                               6963
# aceite                                              6644
# polvo para bebidas sabor chocolate                  6630
# jabon de tocador                                    6394
# pastelillos y pan dulce empaquetado                 5596
# elote                                               5458
# crema                                               5341
#
#
# ==================================================
# CAT?LOGO: NAVIDENOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# vino de mesa                                       23630
# aceituna                                            4469
# sidra                                               3706
# rompope                                             3219
# aceite de oliva                                     1936
# jerez                                               1354
# alcaparra                                           1211
# bacalao                                              955
# pavo                                                 827
# orejon/fruta seca                                    382
# chiles largos en escabeche                           231
# datil                                                209
# turron                                               207
# frutas cubiertas                                      70
# chiles largos o gueros carricillos                    60
# figuras de mazapan                                    51
# pescado seco salado                                   10
# colacion                                               7
# avellana                                               4
#
#
# ==================================================
# CAT?LOGO: PESCADOS Y MARISCOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# mojarra                                            10286
# camaron                                             7637
# calamar                                             6412
# salmon                                              4502
# pulpo                                               3185
# huachinango                                         3105
# almeja                                              3089
# sierra                                              2661
# atun                                                2334
# basa                                                2299
# cazon                                               2201
# jaiba                                               1773
# barrita de surimi o barrita de surimi cangre            1661
# robalo                                              1529
# lisa                                                1354
# bagre                                               1348
# jaibon                                              1243
# pampano                                             1174
# bandera                                             1128
# jurel                                               1104
#
#
# ==================================================
# CAT?LOGO: TENIS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# tenis                                               4306
#
#
# ==================================================
# CAT?LOGO: UTILES ESCOLARES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# colores de madera                                  70869
# cuaderno profesional                               53958
# crayones                                           40917
# boligrafo tinta negra                              36585
# lapiz                                              35562
# lapiz adhesivo                                     24597
# pliegos de papel                                   22859
# plumones                                           22030
# sacapuntas                                         21470
# cuaderno forma francesa                            16414
# goma borrador                                      15975
# pegamento                                          13812
# tijeras                                            13145
# cinta adhesiva                                     12533
# pantalon escuela oficial                           11559
# juego de geometria                                 10715
# diccionario                                        10556
# calculadoras                                       10311
# cuaderno forma italiana                            10259
# portaminas                                         10157
#
#
# ==================================================
# A?O: 2020
# ==================================================
#
#
# ==================================================
# CAT?LOGO: AEROPUERTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                               2
#
#
# ==================================================
# CAT?LOGO: BASICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                          286670
# jamon                                             184472
# shampoo                                           164216
# desodorante                                       153300
# detergente p/ropa                                 129267
# leche ultrapasteurizada                           121925
# jabon de tocador                                  118980
# toalla femenina                                   118265
# papas fritas y similares                          117964
# salchicha                                         112861
# chiles                                             93772
# yoghurt                                            90665
# carne res                                          90358
# leche en polvo                                     86260
# carne cerdo                                        84458
# cafe soluble                                       82872
# pastelillos y pan dulce empaquetado                81374
# mayonesa                                           81129
# atun                                               78752
# agua sin gas                                       78636
#
#
# ==================================================
# CAT?LOGO: ELECTRODOMESTICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# pantallas                                          79711
# lavadoras                                          55378
# estufas                                            49575
# refrigeradores                                     49095
# planchas                                           41816
# licuadoras                                         28983
# horno de microondas                                27116
# componentes de audio                               26655
# cafeteras                                          23528
# batidoras                                          22662
# extractores de jugos y exprimidores                19911
# celulares                                          18793
# dvd / blu ray                                      18152
# bocinas portatiles                                 17244
# camaras digitales                                  14870
# horno electrico                                    12471
# sandwicheras                                       11254
# electronicos de video                              10384
# olla de presion express                            10021
# reproductores streaming                             8900
#
#
# ==================================================
# CAT?LOGO: FRUTAS Y LEGUMBRES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# chile fresco                                       50264
# manzana                                            34239
# cebolla                                            22730
# platano                                            22570
# limon                                              21479
# jitomate                                           20528
# lechuga                                            19930
# col                                                18180
# uva                                                18058
# melon                                              17868
# mango                                              15152
# zanahoria                                          14134
# tomate                                             13380
# pera                                               12347
# papa                                               12204
# papaya                                             11969
# aguacate                                           11825
# pepino                                             11690
# naranja                                            11461
# chayote                                            11443
#
#
# ==================================================
# CAT?LOGO: JUGUETES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# juegos de mesa                                     38637
# varios                                             34787
# munecas                                            24055
# juguetes educativos                                16868
# munecos                                            16290
# juguetes de destreza                               13861
# autopistas                                          8825
# juguetes armables                                   7741
# motos y carros mecanicos                            5672
# videojuegos                                         4410
# munecas electricas                                  4260
# motos y carros electricos                           2583
# munecos electricos                                  1905
# electronicos de video                               1211
# juguetes montables                                   686
# juguetes montables electricos                        116
#
#
# ==================================================
# CAT?LOGO: MEDICAMENTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# tabcin                                             31549
# gel antibacterial                                  26780
# cialis                                             21749
# celestamine-ns                                     21104
# lyrica                                             19902
# micardis                                           19536
# celebrex                                           19436
# lexapro                                            18838
# tempra                                             17458
# cafiaspirina                                       17204
# alevian duo                                        16810
# cubrebocas                                         16293
# levitra                                            15099
# "amoxicilina"amoxicilinaacido clavulanico"           14938
# venda elastica                                     14603
# desenfriol-d                                       14540
# riopan                                             14518
# aspirina                                           14338
# nexium-mups                                        14316
# dolo-neurobion forte                               14153
#
#
# ==================================================
# CAT?LOGO: MERCADOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# carne cerdo                                        23399
# carne res                                          21062
# detergente p/ropa                                  12862
# chile seco                                          9120
# frijol                                              8862
# chiles                                              8294
# limpiador liquido p/piso                            7173
# jamon                                               6639
# mayonesa                                            6405
# carne pollo                                         6296
# aceite                                              5998
# blanqueador                                         5967
# salchicha                                           5550
# mole rojo en pasta                                  5542
# jabon de pasta                                      4907
# crema                                               4705
# jabon de tocador                                    4616
# polvo para bebidas sabor chocolate                  4599
# elote                                               4085
# arroz                                               4043
#
#
# ==================================================
# CAT?LOGO: NAVIDENOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# vino de mesa                                       14389
# aceituna                                            3135
# sidra                                               1705
# rompope                                             1338
# aceite de oliva                                     1289
# jerez                                                965
# alcaparra                                            834
# pavo                                                 739
# bacalao                                              727
# chiles largos en escabeche                           283
# orejon/fruta seca                                    261
# datil                                                205
# turron                                                92
# frutas cubiertas                                      62
# chiles largos o gueros carricillos                    61
# figuras de mazapan                                    15
# colacion                                               6
# pescado seco salado                                    5
#
#
# ==================================================
# CAT?LOGO: PESCADOS Y MARISCOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# mojarra                                             9646
# camaron                                             5924
# calamar                                             3891
# salmon                                              2959
# basa                                                2722
# huachinango                                         2180
# pulpo                                               2038
# almeja                                              1984
# barrita de surimi o barrita de surimi cangre            1974
# sierra                                              1603
# atun                                                1586
# cazon                                               1156
# tilapia                                             1155
# jaiba                                               1108
# robalo                                               808
# lisa                                                 788
# bagre                                                764
# blanco del nilo                                      755
# jurel                                                737
# jaibon                                               630
#
#
# ==================================================
# CAT?LOGO: UTILES ESCOLARES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# colores de madera                                  30586
# cuaderno profesional                               19043
# crayones                                           17337
# lapiz                                              14403
# boligrafo tinta negra                              13807
# lapiz adhesivo                                     12140
# sacapuntas                                          9886
# plumones                                            8740
# pliegos de papel                                    7580
# goma borrador                                       6403
# pegamento                                           6053
# tijeras                                             5289
# cinta adhesiva                                      5246
# cuaderno forma francesa                             5227
# juego de geometria                                  4967
# diccionario                                         4847
# calculadoras                                        4388
# portaminas                                          3952
# cuaderno forma italiana                             3754
# folders                                             3582
#
#
# ==================================================
# A?O: 2021
# ==================================================
#
#
# ==================================================
# CAT?LOGO: BASICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                          311456
# jamon                                             199317
# shampoo                                           178761
# desodorante                                       172265
# leche ultrapasteurizada                           130724
# detergente p/ropa                                 130251
# toalla femenina                                   125960
# salchicha                                         123602
# jabon de tocador                                  122650
# papas fritas y similares                          108390
# chiles                                            108330
# pastelillos y pan dulce empaquetado               101516
# carne res                                         100162
# carne cerdo                                        97277
# yoghurt                                            96581
# huevo                                              95762
# cerveza                                            95483
# cafe soluble                                       92746
# atun                                               85458
# mayonesa                                           84458
#
#
# ==================================================
# CAT?LOGO: ELECTRODOMESTICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# lavadoras                                         103744
# pantallas                                         101667
# estufas                                            87785
# refrigeradores                                     87524
# celulares                                          64906
# horno de microondas                                50502
# planchas                                           50281
# cafeteras                                          41449
# licuadoras                                         41086
# extractores de jugos y exprimidores                40264
# bocinas portatiles                                 30427
# batidoras                                          29019
# dvd / blu ray                                      25127
# horno electrico                                    24874
# sandwicheras                                       22572
# barra de sonido                                    21808
# electronicos de video                              19601
# olla de presion express                            19000
# reproductores streaming                            18585
# componentes de audio                               17816
#
#
# ==================================================
# CAT?LOGO: FRUTAS Y LEGUMBRES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# chile fresco                                       64397
# manzana                                            42211
# platano                                            26661
# cebolla                                            26420
# limon                                              24256
# jitomate                                           23407
# uva                                                22921
# lechuga                                            22096
# col                                                20211
# melon                                              18720
# mango                                              16425
# tomate                                             15930
# zanahoria                                          15856
# papa                                               14217
# aguacate                                           14017
# papaya                                             13988
# pera                                               13889
# pepino                                             13791
# naranja                                            13372
# calabaza                                           13172
#
#
# ==================================================
# CAT?LOGO: JUGUETES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# juegos de mesa                                     46304
# varios                                             34192
# munecas                                            27715
# juguetes educativos                                22419
# juguetes de destreza                               15619
# juguetes armables                                  13041
# munecos                                            12627
# autopistas                                         10009
# munecas electricas                                  6749
# videojuegos                                         6159
# motos y carros mecanicos                            5177
# motos y carros electricos                           2970
# electronicos de video                               2110
# munecos electricos                                  1396
# juguetes montables                                   754
# juguetes montables electricos                         77
#
#
# ==================================================
# CAT?LOGO: MEDICAMENTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# gel antibacterial                                  45671
# tabcin                                             42167
# cubrebocas                                         36825
# cafiaspirina                                       31151
# venda elastica                                     26189
# tempra                                             24718
# cialis                                             23520
# alcohol                                            22095
# celestamine-ns                                     21705
# nebulizador                                        21538
# lyrica                                             21300
# celebrex                                           20965
# guantes de latex                                   20462
# termometro                                         20329
# micardis                                           20057
# lexapro                                            19808
# alevian duo                                        18060
# gasa                                               17942
# desenfriol-d                                       17830
# agua oxigenada                                     17334
#
#
# ==================================================
# CAT?LOGO: MERCADOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# carne res                                          24585
# carne cerdo                                        24411
# detergente p/ropa                                  11426
# chile seco                                         10385
# frijol                                             10119
# chiles                                              9159
# limpiador liquido p/piso                            7242
# carne pollo                                         6999
# aceite                                              6735
# mayonesa                                            5840
# jamon                                               5778
# blanqueador                                         5721
# crema                                               4840
# mole rojo en pasta                                  4767
# jabon de tocador                                    4670
# arroz                                               4555
# salchicha                                           4521
# cafe soluble                                        4203
# atun                                                4184
# jabon de pasta                                      4009
#
#
# ==================================================
# CAT?LOGO: NAVIDENOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# vino de mesa                                       24061
# aceituna                                            4620
# sidra                                               3885
# rompope                                             2331
# aceite de oliva                                     2167
# jerez                                               1397
# alcaparra                                           1326
# bacalao                                             1265
# ...
# Producto                                   Observaciones
# -------------------------------------------------------
# camaron                                            19410
# mojarra                                            18170
# basa                                               16035
# tilapia                                             7521
# calamar                                             6423
# sierra                                              5763
# salmon                                              5497
# huachinango                                         5470
# blanco del nilo                                     4490
# barrita de surimi o barrita de surimi cangre            4045
# pulpo                                               3867
# atun                                                3372
# almeja                                              2762
# cazon                                               2316
# bagre                                               2082
# jaiba                                               1937
# robalo                                              1708
# bandera                                             1468
# lisa                                                1419
# jurel                                               1208
#
#
# ==================================================
# CAT?LOGO: TENIS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# tenis                                               3074
#
#
# ==================================================
# CAT?LOGO: UTILES ESCOLARES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# colores de madera                                  57827
# crayones                                           39037
# cuaderno profesional                               35653
# plumones                                           30371
# lapiz                                              28529
# boligrafo tinta negra                              27255
# sacapuntas                                         18908
# lapiz adhesivo                                     14918
# pliegos de papel                                   14158
# goma borrador                                      13725
# pegamento                                          13027
# cinta adhesiva                                     10821
# juego de geometria                                 10735
# cuaderno forma francesa                             9780
# tijeras                                             8596
# calculadoras                                        7809
# folders                                             7595
# diccionario                                         7559
# cuaderno forma italiana                             7348
# portaminas                                          7037
#
#
# ==================================================
# A?O: 2024
# ==================================================
#
#
# ==================================================
# CAT?LOGO: BASICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# refresco                                           89119
# jamon                                              58062
# toalla femenina                                    57492
# desodorante                                        47872
# shampoo                                            47357
# yoghurt                                            40660
# leche ultrapasteurizada                            36240
# agua sin gas                                       33976
# jabon de tocador                                   33078
# papas fritas y similares                           32666
# cerveza                                            30341
# carne res                                          30274
# chiles                                             29815
# salchicha                                          29638
# detergente p/ropa                                  29396
# pastelillos y pan dulce empaquetado                29058
# carne cerdo                                        28115
# atun                                               27618
# panales desechables                                27224
# aceite                                             24301
#
#
# ==================================================
# CAT?LOGO: ELECTRODOMESTICOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# lavadoras                                          25168
# estufas                                            22831
# pantallas                                          21809
# planchas                                           19501
# refrigeradores                                     19076
# licuadoras                                         15320
# celulares                                          14972
# horno de microondas                                12515
# bocinas portatiles                                 12249
# cafeteras                                          12036
# extractores de jugos y exprimidores                10702
# electronicos de video                               8978
# batidoras                                           8286
# reproductores streaming                             7347
# horno electrico                                     7057
# barra de sonido                                     5837
# sandwicheras                                        5315
# secadoras                                           5036
# freidoras de aire                                   4535
# tostadores de pan                                   4117
#
#
# ==================================================
# CAT?LOGO: FRUTAS Y LEGUMBRES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# chile fresco                                       18068
# manzana                                            13345
# cebolla                                             7430
# platano                                             7396
# limon                                               7293
# jitomate                                            6609
# col                                                 6411
# lechuga                                             6235
# zanahoria                                           5211
# uva                                                 5149
# mango                                               4888
# melon                                               4578
# tomate                                              4395
# papa                                                4112
# papaya                                              3955
# naranja                                             3937
# aguacate                                            3920
# pera                                                3879
# pina                                                3710
# toronja                                             3617
#
#
# ==================================================
# CAT?LOGO: JUGUETES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# varios                                              3610
# juegos de mesa                                      3387
# munecas                                             2535
# juguetes educativos                                 2088
# juguetes de destreza                                1486
# autopistas                                          1229
# munecos                                             1175
# juguetes armables                                    942
# motos y carros mecanicos                             578
# videojuegos                                          531
# munecas electricas                                   398
# electronicos de video                                395
# motos y carros electricos                            375
# munecos electricos                                   312
# juguetes montables                                    52
# juguetes montables electricos                         21
#
#
# ==================================================
# CAT?LOGO: MEDICAMENTOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# gel antibacterial                                  14015
# cubrebocas                                         12566
# tabcin                                             10987
# cafiaspirina                                       10387
# venda elastica                                      7071
# cialis                                              7052
# tempra                                              6924
# celestamine-ns                                      6808
# termometro                                          6235
# celebrex                                            6114
# nebulizador                                         6038
# alcohol                                             5694
# lyrica                                              5348
# guantes de latex                                    5245
# alevian duo                                         5173
# micardis                                            5126
# lexapro                                             4926
# desenfriol-d                                        4777
# dolo-neurobion forte                                4694
# xl-3                                                4678
#
#
# ==================================================
# CAT?LOGO: MERCADOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# carne cerdo                                         6799
# carne res                                           6622
# detergente p/ropa                                   2934
# frijol                                              2699
# chile seco                                          2632
# chiles                                              2529
# carne pollo                                         1795
# aceite                                              1698
# limpiador liquido p/piso                            1668
# blanqueador                                         1450
# jamon                                               1316
# arroz                                               1242
# mole rojo en pasta                                  1155
# salsa picante                                       1036
# crema                                               1010
# salchicha                                            910
# concentrado de pollo                                 908
# jabon de pasta                                       893
# mayonesa                                             890
# pan de caja                                          882
#
#
# ==================================================
# CAT?LOGO: NAVIDENOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# alcaparra                                             78
# chiles largos en escabeche                            38
# vino de mesa                                          30
# aceite de oliva                                       23
# aceituna                                              22
# rompope                                                6
# jerez                                                  3
# sidra                                                  1
# bacalao                                                1
#
#
# ==================================================
# CAT?LOGO: PACIC
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# pasta para sopa                                    21170
# atun                                                8641
# aceite                                              7268
# carne cerdo                                         6893
# papel higienico                                     6617
# arroz                                               6599
# carne pollo                                         6501
# huevo                                               6482
# leche ultrapasteurizada                             6250
# sardina                                             6049
# limon                                               5384
# cebolla                                             5281
# azucar                                              5273
# jitomate                                            5014
# tortilla de maiz                                    4912
# manzana                                             4774
# carne res                                           4728
# chile fresco                                        4713
# papa                                                4390
# frijol                                              4150
#
#
# ==================================================
# CAT?LOGO: PESCADOS Y MARISCOS
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# camaron                                             9625
# basa                                                4787
# mojarra                                             4579
# calamar                                             2684
# salmon                                              2536
# tilapia                                             2230
# barrita de surimi o barrita de surimi cangre            1812
# pulpo                                               1736
# huachinango                                         1707
# atun                                                1597
# sierra                                              1536
# almeja                                              1176
# blanco del nilo                                     1091
# jaiba                                                874
# cazon                                                808
# robalo                                               761
# bagre                                                680
# jurel                                                555
# lisa                                                 553
# bandera                                              523
#
#
# ==================================================
# CAT?LOGO: UTILES ESCOLARES
# ==================================================
# Producto                                   Observaciones
# -------------------------------------------------------
# colores de madera                                   8420
# crayones                                            6040
# cuaderno profesional                                4912
# plumones                                            4653
# lapiz                                               4383
# boligrafo tinta negra                               4144
# sacapuntas                                          3017
# lapiz adhesivo                                      2566
# goma borrador                                       2020
# pliegos de papel                                    1920
# pegamento                                           1900
# juego de geometria                                  1502
# cinta adhesiva                                      1462
# cuaderno forma francesa                             1399
# boligrafo colores varios                            1393
# calculadoras                                        1388
# tijeras                                             1260
# folders                                             1139
# cuaderno forma italiana                             1107
# portaminas                                          1045

# %%
#Guardamos el resultado en un bucket

df_top20.write.mode("overwrite").parquet(f"{BUCKET}/{FOLDER}/catalogos_top_20")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# ### Datos por estado.
#
# Primero vamos a ver que tenemos información de todos los estados de la República:

# %%
#¿Tenemos datos de todos los estados del país?
no_estados = df_parquet.select("estado").distinct().count()
if (no_estados < 32):
    print("No hay información de todos los estados")
elif (no_estados > 32):  
    print("PROBLEMA: Hay más de 32 estados\n Revisa la limpieza de datos")
else: 
    print("Hay información de todos los estados")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Hay informaci?n de todos los estados

# %% [markdown]
# Imprimimos ahora los nombres de los estados para revisar que todo lo está haciendo correcto.

# %%
#Mostramos los estados
df_parquet.select("estado").distinct().show(32)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+
# |              estado|
# +--------------------+
# |          tamaulipas|
# |           zacatecas|
# |          nuevo leon|
# |            campeche|
# |     san luis potosi|
# |            veracruz|
# |             morelos|
# |          guanajuato|
# |              sonora|
# |            tlaxcala|
# |             nayarit|
# |             sinaloa|
# |              oaxaca|
# |            guerrero|
# |        quintana roo|
# |           queretaro|
# |    estado de mexico|
# |              puebla|
# |             durango|
# |             jalisco|
# |      aguascalientes|
# |coahuila de zaragoza|
# | baja california sur|
# |              colima|
# |             tabasco|
# |           chihuahua|
# |     baja california|
# |    ciudad de mexico|
# |             yucatan|
# |             chiapas|
# |             hidalgo|
# | michoacan de ocampo|
# +--------------------+

# %% [markdown]
# #### Nº de catálogos por estado y por año.

# %%
from pyspark.sql import functions as F

#CONSULTA
# Agrupamos directamente por año y estado
df_catalogos_por_estado = df_parquet.groupBy("anio", "estado") \
    .agg(F.countDistinct("catalogo").alias("No_Catalogos")) \
    .orderBy("anio", "estado")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#IMPRESION
rows = df_catalogos_por_estado.collect()

from itertools import groupby

for anio, grupo_anio in groupby(rows, key=lambda r: r['anio']):
    print(f"\n\n{'='*50}")
    print(f"AÑO: {anio}")
    print(f"{'='*50}")
    print(f"{'Estado':<30} {'No. Catalogos':>15}")
    print("-" * 45)
    for row in grupo_anio:
        print(f"{row['estado']:<30} {row['No_Catalogos']:>15}")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ==================================================
# A?O: 2018
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                               9
# baja california                             10
# baja california sur                          9
# campeche                                     9
# chiapas                                     10
# chihuahua                                   10
# ciudad de mexico                            10
# coahuila de zaragoza                        10
# colima                                      10
# durango                                     10
# estado de mexico                            10
# guanajuato                                  10
# guerrero                                    10
# hidalgo                                     10
# jalisco                                     10
# michoacan de ocampo                          9
# morelos                                      9
# nayarit                                     10
# nuevo leon                                  10
# oaxaca                                      10
# puebla                                       9
# queretaro                                    9
# quintana roo                                10
# san luis potosi                             10
# sinaloa                                     10
# sonora                                      10
# tabasco                                     10
# tamaulipas                                  10
# tlaxcala                                    10
# veracruz                                    10
# yucatan                                     10
# zacatecas                                   10
#
#
# ==================================================
# A?O: 2019
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                              11
# baja california                             10
# baja california sur                         10
# campeche                                     9
# chiapas                                     10
# chihuahua                                   11
# ciudad de mexico                            10
# coahuila de zaragoza                         9
# colima                                      10
# durango                                     10
# estado de mexico                            10
# guanajuato                                  10
# guerrero                                    10
# hidalgo                                     11
# jalisco                                     10
# michoacan de ocampo                          9
# morelos                                      9
# nayarit                                      8
# nuevo leon                                  10
# oaxaca                                       9
# puebla                                       9
# queretaro                                   10
# quintana roo                                10
# san luis potosi                             11
# sinaloa                                      9
# sonora                                      10
# tabasco                                     10
# tamaulipas                                  10
# tlaxcala                                    10
# veracruz                                    11
# yucatan                                     10
# zacatecas                                   10
#
#
# ==================================================
# A?O: 2020
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                               9
# baja california                              9
# baja california sur                          9
# campeche                                     9
# chiapas                                      9
# chihuahua                                    5
# ciudad de mexico                             9
# coahuila de zaragoza                         9
# colima                                       4
# durango                                      9
# estado de mexico                             9
# guanajuato                                   9
# guerrero                                     8
# hidalgo                                      9
# jalisco                                      9
# michoacan de ocampo                          9
# morelos                                      5
# nayarit                                      3
# nuevo leon                                   9
# oaxaca                                       9
# puebla                                       8
# queretaro                                    9
# quintana roo                                 9
# san luis potosi                              9
# sinaloa                                      9
# sonora                                       6
# tabasco                                      9
# tamaulipas                                   9
# tlaxcala                                     9
# veracruz                                     9
# yucatan                                     10
# zacatecas                                    9
#
#
# ==================================================
# A?O: 2021
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                              10
# baja california                              9
# baja california sur                         10
# campeche                                    10
# chiapas                                      9
# chihuahua                                   10
# ciudad de mexico                            10
# coahuila de zaragoza                        10
# durango                                     10
# estado de mexico                            10
# guanajuato                                  10
# guerrero                                     8
# hidalgo                                      9
# jalisco                                     10
# michoacan de ocampo                         10
# morelos                                     10
# nuevo leon                                  10
# oaxaca                                      10
# puebla                                       9
# queretaro                                   10
# quintana roo                                10
# san luis potosi                             10
# sinaloa                                      9
# sonora                                      10
# tabasco                                      9
# tamaulipas                                  10
# tlaxcala                                    10
# veracruz                                    10
# yucatan                                     10
# zacatecas                                   10
#
#
# ==================================================
# A?O: 2022
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                              11
# baja california                             11
# baja california sur                         11
# campeche                                    11
# chiapas                                     10
# chihuahua                                   11
# ciudad de mexico                            11
# coahuila de zaragoza                        11
# durango                                     11
# estado de mexico                            11
# guanajuato                                  11
# guerrero                                     8
# hidalgo                                     10
# jalisco                                     11
# michoacan de ocampo                         11
# morelos                                     11
# nuevo leon                                  11
# oaxaca                                      10
# puebla                                      10
# queretaro                                   11
# quintana roo                                11
# san luis potosi                             11
# sinaloa                                     10
# sonora                                      11
# tabasco                                     11
# tamaulipas                                  10
# tlaxcala                                    11
# veracruz                                    11
# yucatan                                     11
# zacatecas                                   11
#
#
# ==================================================
# A?O: 2023
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                              11
# baja california                             11
# baja california sur                         11
# campeche                                    11
# chiapas                                     10
# chihuahua                                   11
# ciudad de mexico                            11
# coahuila de zaragoza                        11
# durango                                     11
# estado de mexico                            11
# guanajuato                                  11
# guerrero                                     7
# hidalgo                                     11
# jalisco                                     11
# michoacan de ocampo                         11
# morelos                                     11
# nuevo leon                                  11
# oaxaca                                      10
# puebla                                      10
# queretaro                                   11
# quintana roo                                10
# san luis potosi                             11
# sinaloa                                      6
# sonora                                      11
# tabasco                                     11
# tamaulipas                                  11
# tlaxcala                                    11
# veracruz                                    10
# yucatan                                     11
# zacatecas                                   11
#
#
# ==================================================
# A?O: 2024
# ==================================================
# Estado                           No. Catalogos
# ---------------------------------------------
# aguascalientes                               9
# baja california                             10
# baja california sur                         10
# campeche                                     9
# chiapas                                      8
# chihuahua                                   10
# ciudad de mexico                            10
# coahuila de zaragoza                        10
# durango                                      9
# estado de mexico                            10
# guanajuato                                   9
# guerrero                                     9
# hidalgo                                      8
# jalisco                                     10
# michoacan de ocampo                         10
# morelos                                     10
# nuevo leon                                  10
# oaxaca                                       9
# puebla                                       9
# queretaro                                   10
# quintana roo                                 9
# san luis potosi                              9
# sinaloa                                      5
# sonora                                       9
# tabasco                                      9
# tamaulipas                                  10
# tlaxcala                                     9
# veracruz                                    10
# yucatan                                     10
# zacatecas                                   10

# %% [markdown]
# ### Para cada estado: Mayor y Menor número de catálogos por año
#
# Los años mostrados como dónde se alcanzó el máximo y el mínimo no son necesariamente únicos.

# %%
#De cada estado: obtenemos el menor y el mayor número de catálogos por año. 
#Los años no necesariamente únicos

from pyspark.sql.window import Window
from pyspark.sql import functions as F

# Base: catálogos por estado y año
catalogos_por_estado_anio = df_parquet.groupBy("estado", "anio") \
    .agg(F.countDistinct("catalogo").alias("count"))

# Ventanas por estado ordenadas por count
window_min = Window.partitionBy("estado").orderBy("count")
window_max = Window.partitionBy("estado").orderBy(F.desc("count"))

# Filtramos solo una fila por estado (la de menor y mayor count)
df_min = catalogos_por_estado_anio \
    .withColumn("rn", F.row_number().over(window_min)) \
    .filter(F.col("rn") == 1) \
    .select("estado", F.col("anio").alias("anho_min"), F.col("count").alias("min_catalogos"))

df_max = catalogos_por_estado_anio \
    .withColumn("rn", F.row_number().over(window_max)) \
    .filter(F.col("rn") == 1) \
    .select("estado", F.col("anio").alias("anho_max"), F.col("count").alias("max_catalogos"))

# Unimos resultados
resultado = df_min.join(df_max, on="estado").orderBy("estado")

resultado.show(32, truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+--------+-------------+--------+-------------+
# |estado              |anho_min|min_catalogos|anho_max|max_catalogos|
# +--------------------+--------+-------------+--------+-------------+
# |aguascalientes      |2024    |9            |2019    |11           |
# |baja california     |2021    |9            |2022    |11           |
# |baja california sur |2018    |9            |2023    |11           |
# |campeche            |2024    |9            |2023    |11           |
# |chiapas             |2024    |8            |2019    |10           |
# |chihuahua           |2020    |5            |2019    |11           |
# |ciudad de mexico    |2020    |9            |2023    |11           |
# |coahuila de zaragoza|2020    |9            |2022    |11           |
# |colima              |2020    |4            |2019    |10           |
# |durango             |2024    |9            |2022    |11           |
# |estado de mexico    |2020    |9            |2023    |11           |
# |guanajuato          |2024    |9            |2023    |11           |
# |guerrero            |2023    |7            |2019    |10           |
# |hidalgo             |2024    |8            |2023    |11           |
# |jalisco             |2020    |9            |2022    |11           |
# |michoacan de ocampo |2020    |9            |2023    |11           |
# |morelos             |2020    |5            |2023    |11           |
# |nayarit             |2020    |3            |2018    |10           |
# |nuevo leon          |2020    |9            |2023    |11           |
# |oaxaca              |2020    |9            |2023    |10           |
# |puebla              |2020    |8            |2023    |10           |
# |queretaro           |2020    |9            |2023    |11           |
# |quintana roo        |2024    |9            |2022    |11           |
# |san luis potosi     |2024    |9            |2019    |11           |
# |sinaloa             |2024    |5            |2022    |10           |
# |sonora              |2020    |6            |2023    |11           |
# |tabasco             |2024    |9            |2023    |11           |
# |tamaulipas          |2020    |9            |2023    |11           |
# |tlaxcala            |2024    |9            |2023    |11           |
# |veracruz            |2020    |9            |2019    |11           |
# |yucatan             |2021    |10           |2023    |11           |
# |zacatecas           |2020    |9            |2023    |11           |
# +--------------------+--------+-------------+--------+-------------+

# %% [markdown]
# ## Del catálogo BASICOS
#
# Las preguntas que se muestran en esta sección se refieren sólo al catálog **Básicos** que fue el asignado a nuestro grupo.
#
# Para acelerar las búsquedas, creamos un primer dataframe filtrado por catálogo, para así no tener que especificar siempre el catálogo.

# %%
#¿Cuańtas marcas diferentes tiene tu categoría?(basicos)
CATALOG_TYPE = "basicos"
df_basicos = df_parquet.filter(col("catalogo") == CATALOG_TYPE)
df_basicos.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- producto: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- tipo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fecha: date (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- anio: integer (nullable = true)

# %% [markdown]
# ### Número de marcas diferentes que aparecen en nuestra categoría.

# %%
#Contamos número de marcas
df_basicos.select("marca").distinct().count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 637

# %% [markdown]
# Las preguntas que se hacen en esta sección hablan de marcas. En nuestro caso, no tiene mucho sentido mostrar sólo la marca, pues se puede referir a productos muy diversos. Así pues, consideramos siempre el par **producto-marca**
#
# ### Marca con mayor precio
#
# ##### ¿Cuál es la marca con mayor precio? ¿En qué estado se encuentra?
# Como tenemos información de varios años, consideraremos el precio promedio.

# %%
from pyspark.sql.functions import avg
# ¿Cuál es la marca con mayor precio? ¿En qué estado?
#Vamos a contestar al producto, pues la marca no tiene mucho sentido. 
mayor_promedio = df_basicos.groupBy("producto", "marca", "estado")\
                            .agg(avg("precio").alias("precio_prom"))\
                            .orderBy(col("precio_prom").desc())
mayor_promedio.show(15)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------+----------+-------------------+-----------------+
# |      producto|     marca|             estado|      precio_prom|
# +--------------+----------+-------------------+-----------------+
# |copa menstrual|diva cup 2|       quintana roo|723.3333333333334|
# |copa menstrual|diva cup 2|           veracruz|            690.0|
# |copa menstrual|diva cup 2|          queretaro| 677.452380952381|
# |copa menstrual|diva cup 2|             puebla|            674.0|
# |copa menstrual|diva cup 2|baja california sur|644.0666666666667|
# |copa menstrual|diva cup 2|          zacatecas|634.2105263157895|
# |copa menstrual|diva cup 2|   ciudad de mexico|628.6392307491093|
# |copa menstrual|diva cup 1|             puebla|628.3589743589744|
# |copa menstrual|diva cup 1|          chihuahua|619.9000244140625|
# |copa menstrual|diva cup 1|          queretaro|615.6611111111112|
# |copa menstrual|diva cup 1|            durango|615.5914515904018|
# |copa menstrual|diva cup 1|          zacatecas|614.4038614126353|
# |copa menstrual|diva cup 1|           veracruz|            614.0|
# |copa menstrual|diva cup 1|       quintana roo|            614.0|
# |copa menstrual|diva cup 2|         nuevo leon|612.9634703196347|
# +--------------+----------+-------------------+-----------------+
# only showing top 15 rows

# %% [markdown]
# Por los resultados observados el producto más caro es la **Copa Menstrual** en el estado de **Quintana Roo**, además observamos que este producto está en el top 10 de los más caros, ya que la tabla anterior está ordenada por precio promedio, con lo que si hubiera en el estado de Veracruz un producto más barato que la copa menstrual en el estado de Querétaro, aparcería en tercer lugar.

# %% [markdown]
# ### En la CDMX
# Queremos saber cuáles son los productos más baratos. De nuevo tomamos el promedio anual.

# %%
from pyspark.sql.functions import min
# ¿Cuál es el producto/marca con menor precio promedio en CDMX?
menor_precio_promedio_cdmx = df_basicos.filter(col("estado") == "ciudad de mexico")\
    .groupBy("producto", "marca")\
    .agg(avg("precio").alias("precio_promedio"))\
    .orderBy("precio_promedio")

menor_precio_promedio_cdmx.show(5, truncate = False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------------------+--------+------------------+
# |producto                |marca   |precio_promedio   |
# +------------------------+--------+------------------+
# |pan blanco bolillo      |s/m     |1.7916649643842255|
# |polvo p/preparar bebidas|frutimax|2.3564714899777206|
# |polvo p/preparar bebidas|clight  |3.165304193614619 |
# |pasta para sopa         |soriana |3.3124000021616617|
# |polvo p/preparar bebidas|livean  |3.331467661988083 |
# +------------------------+--------+------------------+
# only showing top 5 rows

# %% [markdown]
# ## Marcas con más observaciones
#
# Hacemos ahora un análisis de las marcas que tienen más observaciones, a nivel nacional

# %%
# ¿Cuál es la marca con mayores observaciones?
df_basicos.groupBy("marca")\
        .agg(F.count("*").alias("observaciones"))\
        .orderBy(col("observaciones").desc())\
        .show(1)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----+-------------+
# |marca|observaciones|
# +-----+-------------+
# |  s/m|      2762155|
# +-----+-------------+
# only showing top 1 row

# %% [markdown]
# ## Análisis de los precios por marca.
#
# De nuevo consideramos el precio promedio a lo largo de los años por producto-marca, pues nos parece más explicativo.
#
# #### ¿Cuáles son el top 5 de marcas con mayor precio en cada estado? ¿Son diferentes?

# %%
#¿Cuáles son el top 5 de marcas con mayor precio en cada estado? ¿Son diferentes?
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from itertools import groupby


#CONSULTA
# 1. Promedio de precio por estado, producto y marca
df_avg = df_basicos.groupBy("estado", "producto", "marca") \
    .agg(F.avg("precio").alias("precio_promedio"))

# 2. Crear una ventana por estado, ordenando por precio promedio descendente
window = Window.partitionBy("estado").orderBy(F.desc("precio_promedio"))

# 3. Agregar ranking
df_ranked_avg = df_avg.withColumn("rank", F.row_number().over(window))

# 4. Filtrar top 5 por estado
df_top5_avg = df_ranked_avg.filter(col("rank") <= 5).orderBy("estado")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#IMPRESION

rows = df_top5_avg.select("estado", "producto", "marca", "precio_promedio", "rank").collect()

for estado, grupo_estado in groupby(rows, key=lambda r: r['estado']):
    print(f"\n\n{'='*50}")
    print(f"ESTADO: {estado.upper()}")
    print(f"{'='*50}")
    print(f"{'Producto':<30} {'Marca':<25} {'Precio Promedio':>18}")
    print("-" * 75)
    for row in grupo_estado:
        print(f"{row['producto']:<30} {row['marca']:<25} {row['precio_promedio']:>18.2f}")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ==================================================
# ESTADO: AGUASCALIENTES
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              573.35
# copa menstrual                 diva cup 2                            541.11
# copa menstrual                 diva cup 1                            505.58
# nuez                           s/m                                   422.31
# tequila                        jose cuervo tradicional               368.82
#
#
# ==================================================
# ESTADO: BAJA CALIFORNIA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 1                            550.38
# copa menstrual                 saba cup                              543.08
# nuez                           s/m                                   473.05
# almendras                      s/m                                   351.48
# tequila                        jose cuervo tradicional               325.92
#
#
# ==================================================
# ESTADO: BAJA CALIFORNIA SUR
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            644.07
# copa menstrual                 diva cup 1                            604.07
# copa menstrual                 saba cup                              551.51
# nuez                           s/m                                   489.28
# tequila                        jose cuervo tradicional               359.40
#
#
# ==================================================
# ESTADO: CAMPECHE
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              580.00
# nuez                           s/m                                   453.88
# tequila                        jose cuervo tradicional               341.75
# camaron                        s/m                                   338.10
# tequila                        cazadores                             307.24
#
#
# ==================================================
# ESTADO: CHIAPAS
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              580.00
# copa menstrual                 diva cup 2                            557.22
# copa menstrual                 diva cup 1                            556.91
# nuez                           s/m                                   394.45
# tequila                        jose cuervo tradicional               331.32
#
#
# ==================================================
# ESTADO: CHIHUAHUA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 1                            619.90
# copa menstrual                 saba cup                              525.87
# nuez                           s/m                                   393.61
# tequila                        jose cuervo tradicional               375.50
# brandy                         torres 10                             333.19
#
#
# ==================================================
# ESTADO: CIUDAD DE MEXICO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            628.64
# copa menstrual                 diva cup 1                            596.22
# copa menstrual                 saba cup                              546.92
# nuez                           s/m                                   458.45
# tequila                        jose cuervo tradicional               360.03
#
#
# ==================================================
# ESTADO: COAHUILA DE ZARAGOZA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            597.22
# copa menstrual                 diva cup 1                            596.49
# copa menstrual                 saba cup                              568.67
# camaron                        s/m                                   429.90
# nuez                           s/m                                   422.06
#
#
# ==================================================
# ESTADO: COLIMA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# nuez                           s/m                                   393.00
# tequila                        jose cuervo tradicional               296.02
# whisky                         johnnie walker. red label             279.68
# brandy                         torres 10                             271.34
# panales desechables            huggies. ultra confort                238.45
#
#
# ==================================================
# ESTADO: DURANGO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 1                            615.59
# tequila                        jose cuervo tradicional               345.91
# nuez                           s/m                                   323.11
# whisky                         johnnie walker. red label             311.82
# brandy                         torres 10                             310.78
#
#
# ==================================================
# ESTADO: ESTADO DE MEXICO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            611.50
# copa menstrual                 diva cup 1                            585.79
# copa menstrual                 saba cup                              546.33
# nuez                           s/m                                   444.91
# camaron                        s/m                                   363.86
#
#
# ==================================================
# ESTADO: GUANAJUATO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            597.64
# copa menstrual                 diva cup 1                            575.83
# copa menstrual                 saba cup                              549.12
# nuez                           s/m                                   504.43
# tequila                        jose cuervo tradicional               357.58
#
#
# ==================================================
# ESTADO: GUERRERO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 1                            587.50
# copa menstrual                 diva cup 2                            587.50
# copa menstrual                 saba cup                              561.50
# nuez                           s/m                                   428.03
# tequila                        jose cuervo tradicional               326.88
#
#
# ==================================================
# ESTADO: HIDALGO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              527.80
# nuez                           s/m                                   360.00
# tequila                        jose cuervo tradicional               324.06
# almendras                      s/m                                   310.89
# whisky                         johnnie walker. red label             297.38
#
#
# ==================================================
# ESTADO: JALISCO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            585.39
# copa menstrual                 saba cup                              577.84
# copa menstrual                 diva cup 1                            555.67
# nuez                           s/m                                   419.68
# tequila                        jose cuervo tradicional               350.70
#
#
# ==================================================
# ESTADO: MICHOACAN DE OCAMPO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              522.52
# tequila                        jose cuervo tradicional               348.31
# nuez                           s/m                                   338.25
# tequila                        cazadores                             318.61
# whisky                         johnnie walker. red label             309.98
#
#
# ==================================================
# ESTADO: MORELOS
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            612.69
# copa menstrual                 diva cup 1                            577.51
# copa menstrual                 saba cup                              558.50
# tequila                        jose cuervo tradicional               358.16
# tequila                        cazadores                             344.50
#
#
# ==================================================
# ESTADO: NAYARIT
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# nuez                           s/m                                   372.92
# whisky                         johnnie walker. red label             286.32
# tequila                        jose cuervo tradicional               280.63
# brandy                         torres 10                             278.98
# camaron                        s/m                                   271.33
#
#
# ==================================================
# ESTADO: NUEVO LEON
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            612.96
# copa menstrual                 diva cup 1                            602.73
# copa menstrual                 saba cup                              538.28
# nuez                           s/m                                   401.59
# tequila                        jose cuervo tradicional               356.17
#
#
# ==================================================
# ESTADO: OAXACA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              532.90
# copa menstrual                 diva cup 2                            507.75
# copa menstrual                 diva cup 1                            498.59
# nuez                           s/m                                   442.94
# tequila                        jose cuervo tradicional               354.78
#
#
# ==================================================
# ESTADO: PUEBLA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            674.00
# copa menstrual                 diva cup 1                            628.36
# nuez                           s/m                                   504.51
# camaron                        s/m                                   364.26
# tequila                        jose cuervo tradicional               348.30
#
#
# ==================================================
# ESTADO: QUERETARO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            677.45
# copa menstrual                 diva cup 1                            615.66
# copa menstrual                 saba cup                              558.25
# nuez                           s/m                                   466.22
# tequila                        jose cuervo tradicional               356.01
#
#
# ==================================================
# ESTADO: QUINTANA ROO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            723.33
# copa menstrual                 diva cup 1                            614.00
# copa menstrual                 saba cup                              587.31
# nuez                           s/m                                   444.76
# tequila                        jose cuervo tradicional               334.47
#
#
# ==================================================
# ESTADO: SAN LUIS POTOSI
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            591.33
# copa menstrual                 diva cup 1                            591.17
# copa menstrual                 saba cup                              555.54
# nuez                           s/m                                   466.34
# camaron                        s/m                                   439.60
#
#
# ==================================================
# ESTADO: SINALOA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# nuez                           s/m                                   533.37
# almendras                      s/m                                   348.25
# camaron                        s/m                                   310.19
# brandy                         torres 10                             296.19
# tequila                        jose cuervo tradicional               291.67
#
#
# ==================================================
# ESTADO: SONORA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              513.47
# nuez                           s/m                                   511.52
# almendras                      s/m                                   326.68
# brandy                         torres 10                             305.72
# whisky                         johnnie walker. red label             298.94
#
#
# ==================================================
# ESTADO: TABASCO
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            598.00
# copa menstrual                 diva cup 1                            598.00
# copa menstrual                 saba cup                              542.30
# nuez                           s/m                                   486.30
# tequila                        jose cuervo tradicional               338.92
#
#
# ==================================================
# ESTADO: TAMAULIPAS
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            598.00
# copa menstrual                 saba cup                              589.00
# nuez                           s/m                                   422.74
# copa menstrual                 diva cup 1                            420.00
# almendras                      s/m                                   326.36
#
#
# ==================================================
# ESTADO: TLAXCALA
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# canela                         sin marca                             567.40
# nuez                           s/m                                   343.26
# tequila                        jose cuervo tradicional               343.01
# brandy                         torres 10                             296.51
# panales desechables            huggies. ultra confort                295.00
#
#
# ==================================================
# ESTADO: VERACRUZ
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            690.00
# copa menstrual                 diva cup 1                            614.00
# nuez                           s/m                                   341.81
# tequila                        jose cuervo tradicional               314.01
# panales desechables            huggies. ultra confort                287.01
#
#
# ==================================================
# ESTADO: YUCATAN
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 saba cup                              549.76
# nuez                           s/m                                   425.56
# tequila                        jose cuervo tradicional               334.50
# almendras                      s/m                                   325.14
# camaron                        s/m                                   306.06
#
#
# ==================================================
# ESTADO: ZACATECAS
# ==================================================
# Producto                       Marca                        Precio Promedio
# ---------------------------------------------------------------------------
# copa menstrual                 diva cup 2                            634.21
# copa menstrual                 diva cup 1                            614.40
# copa menstrual                 saba cup                              532.70
# nuez                           s/m                                   427.50
# almendras                      s/m                                   420.00

# %% [markdown]
# Con esta visualización es más fácil darse cuenta que el producto básico más caro es la copa menstrual, y en estados como Campeche, donde sólo parece que venden una marca de copa menstrual, entonces aparecen otros productos como la nuez, el tequila o el camarón.

# %% [markdown]
# #### ¿Cuáles son el top 5 de marcas con menor precio en CDMX? (en aquel entonces Distrito Federal)

# %%
df_cdmx = df_basicos.filter(col("estado") == "ciudad de mexico")\
            .groupBy("producto", "marca") \
            .agg(F.avg("precio").alias("precio_promedio"))\
            .orderBy("precio_promedio")\
            .show(5, truncate = False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +------------------------+--------+------------------+
# |producto                |marca   |precio_promedio   |
# +------------------------+--------+------------------+
# |pan blanco bolillo      |s/m     |1.7916649643842255|
# |polvo p/preparar bebidas|frutimax|2.3564714899777206|
# |polvo p/preparar bebidas|clight  |3.165304193614619 |
# |pasta para sopa         |soriana |3.3124000021616617|
# |polvo p/preparar bebidas|livean  |3.331467661988083 |
# +------------------------+--------+------------------+
# only showing top 5 rows

# %% [markdown]
# ####  ¿Cuáles son el top 5 de marcas con mayores observaciones? ¿Se parecen a las de nivel por estado?

# %%
# ¿Cuál es la marca con mayores observaciones?
df_basicos.groupBy("marca")\
        .agg(F.count("*").alias("observaciones"))\
        .orderBy(col("observaciones").desc())\
        .show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----------+-------------+
# |     marca|observaciones|
# +----------+-------------+
# |       s/m|      2762155|
# |la costena|      1311513|
# |       fud|      1151111|
# |     bimbo|       819541|
# |      lala|       750189|
# +----------+-------------+
# only showing top 5 rows

# %% [markdown]
# Veamos ahora las observaciones por estado.

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from itertools import groupby

#CONSULTA
# Agrupamos por estado y marca, y contamos observaciones
df_marca_estado = df_basicos.groupBy("estado", "marca") \
    .agg(F.count("*").alias("observaciones"))

# Definimos una ventana particionada por estado y ordenada por observaciones desc
window_estado = Window.partitionBy("estado").orderBy(F.desc("observaciones"))

# Aplicamos una fila numérica para rankear
df_top5 = df_marca_estado.withColumn("rank", F.row_number().over(window_estado)) \
                         .filter(F.col("rank") <= 5) \
                         .orderBy("estado", "rank")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#IMPRESION

rows = df_top5.select("estado", "marca", "observaciones", "rank").collect()

for estado, grupo_estado in groupby(rows, key=lambda r: r['estado']):
    print(f"\n\n{'='*50}")
    print(f"ESTADO: {estado.upper()}")
    print(f"{'='*50}")
    print(f"{'Marca':<25} {'Observaciones':>10}")
    print("-" * 50)
    for row in grupo_estado:
        print(f"{row['marca']:<25} {row['observaciones']:>10.2f}")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ==================================================
# ESTADO: AGUASCALIENTES
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         52322.00
# fud                         20041.00
# la costena                  18908.00
# bimbo                       15595.00
# lala                        12561.00
#
#
# ==================================================
# ESTADO: BAJA CALIFORNIA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         47708.00
# la costena                  21335.00
# fud                         15562.00
# bimbo                       14915.00
# lala                        13911.00
#
#
# ==================================================
# ESTADO: BAJA CALIFORNIA SUR
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         44265.00
# la costena                  20512.00
# fud                         17289.00
# bimbo                       13981.00
# lala                        13378.00
#
#
# ==================================================
# ESTADO: CAMPECHE
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         43183.00
# fud                         24039.00
# la costena                  22587.00
# bimbo                       15845.00
# sabritas                    15223.00
#
#
# ==================================================
# ESTADO: CHIAPAS
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         39417.00
# la costena                  21191.00
# bimbo                       14073.00
# fud                         12214.00
# clemente jacques            10413.00
#
#
# ==================================================
# ESTADO: CHIHUAHUA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         50827.00
# la costena                  33264.00
# bimbo                       17982.00
# marinela                    15390.00
# sabritas                    14713.00
#
#
# ==================================================
# ESTADO: CIUDAD DE MEXICO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                        672470.00
# la costena                 289837.00
# fud                        286373.00
# bimbo                      170157.00
# lala                       169894.00
#
#
# ==================================================
# ESTADO: COAHUILA DE ZARAGOZA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         53893.00
# la costena                  23157.00
# fud                         23020.00
# lala                        15119.00
# bimbo                       13575.00
#
#
# ==================================================
# ESTADO: COLIMA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         15372.00
# la costena                   8919.00
# fud                          7569.00
# bimbo                        6201.00
# lala                         5468.00
#
#
# ==================================================
# ESTADO: DURANGO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         37433.00
# la costena                  21484.00
# fud                         17714.00
# bimbo                       15502.00
# lala                        14776.00
#
#
# ==================================================
# ESTADO: ESTADO DE MEXICO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                        451509.00
# la costena                 206675.00
# fud                        205318.00
# lala                       117606.00
# sabritas                   116235.00
#
#
# ==================================================
# ESTADO: GUANAJUATO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         97015.00
# la costena                  44266.00
# fud                         38775.00
# bimbo                       29171.00
# lala                        28553.00
#
#
# ==================================================
# ESTADO: GUERRERO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         30939.00
# la costena                  17165.00
# fud                         12055.00
# bimbo                       10977.00
# lala                         8608.00
#
#
# ==================================================
# ESTADO: HIDALGO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         26808.00
# la costena                  13133.00
# fud                          9955.00
# bimbo                        7244.00
# lala                         6456.00
#
#
# ==================================================
# ESTADO: JALISCO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                        122279.00
# la costena                  59326.00
# fud                         51161.00
# lala                        38559.00
# bimbo                       37533.00
#
#
# ==================================================
# ESTADO: MICHOACAN DE OCAMPO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         54108.00
# la costena                  23512.00
# fud                         15900.00
# bimbo                       11924.00
# lala                        11803.00
#
#
# ==================================================
# ESTADO: MORELOS
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         41021.00
# la costena                  17162.00
# fud                         12424.00
# clemente jacques             9586.00
# bimbo                        8885.00
#
#
# ==================================================
# ESTADO: NAYARIT
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                          9896.00
# la costena                   3844.00
# fud                          3407.00
# lala                         2670.00
# bimbo                        2146.00
#
#
# ==================================================
# ESTADO: NUEVO LEON
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         86329.00
# la costena                  47369.00
# fud                         44848.00
# bimbo                       34432.00
# sabritas                    31032.00
#
#
# ==================================================
# ESTADO: OAXACA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         41729.00
# la costena                  23591.00
# fud                         17455.00
# bimbo                       14248.00
# lala                        12686.00
#
#
# ==================================================
# ESTADO: PUEBLA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         73001.00
# la costena                  30818.00
# fud                         27938.00
# bimbo                       22363.00
# sabritas                    20669.00
#
#
# ==================================================
# ESTADO: QUERETARO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         67634.00
# la costena                  34674.00
# fud                         25237.00
# bimbo                       21718.00
# clemente jacques            17555.00
#
#
# ==================================================
# ESTADO: QUINTANA ROO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         83439.00
# la costena                  40274.00
# fud                         39484.00
# sabritas                    26080.00
# bimbo                       23989.00
#
#
# ==================================================
# ESTADO: SAN LUIS POTOSI
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         49447.00
# la costena                  20912.00
# fud                         16924.00
# bimbo                       14708.00
# lala                        12937.00
#
#
# ==================================================
# ESTADO: SINALOA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         38678.00
# la costena                  18654.00
# bimbo                       14462.00
# lala                        12181.00
# sabritas                    10788.00
#
#
# ==================================================
# ESTADO: SONORA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         54178.00
# la costena                  30472.00
# bimbo                       19377.00
# fud                         18458.00
# lala                        17121.00
#
#
# ==================================================
# ESTADO: TABASCO
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         69338.00
# la costena                  38068.00
# fud                         30005.00
# bimbo                       21832.00
# sabritas                    20295.00
#
#
# ==================================================
# ESTADO: TAMAULIPAS
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         48247.00
# la costena                  30131.00
# fud                         22777.00
# bimbo                       19691.00
# sabritas                    15677.00
#
#
# ==================================================
# ESTADO: TLAXCALA
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         50671.00
# la costena                  25408.00
# fud                         22904.00
# bimbo                       18766.00
# lala                        16421.00
#
#
# ==================================================
# ESTADO: VERACRUZ
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         86014.00
# la costena                  34614.00
# fud                         31151.00
# bimbo                       25053.00
# lala                        21009.00
#
#
# ==================================================
# ESTADO: YUCATAN
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         60702.00
# la costena                  35101.00
# fud                         28938.00
# bimbo                       21787.00
# sabritas                    19761.00
#
#
# ==================================================
# ESTADO: ZACATECAS
# ==================================================
# Marca                     Observaciones
# --------------------------------------------------
# s/m                         62283.00
# la costena                  35150.00
# fud                         29992.00
# bimbo                       26517.00
# sabritas                    21211.00

# %% [markdown]
# De la primera salida, observamos más claramente que en la mayoría de los casos, las marcas más observadas son **"s/m"="Sin Marca"**, **fud** y **la costeña**. En algunos estados cambia el orden del 2º y 3º, y en otros sólo aparece uno de los dos en esas posiciones, ocupando la faltante otras marcas.

# %% [markdown]
# ##### ¿Ha dejado de existir alguna marca durante los años que tienes? ¿Cuál? ¿Cuándo desapareció?

# %%
#CONSULTA
# Paso 1: obtener el máximo año registrado
max_anio = df_basicos.agg(F.max("anio")).first()[0]

# Paso 2: obtener presencia de cada marca por año
df_marca_anio = df_basicos.select("marca", "anio").distinct()

# Paso 3: obtener el último año en que se vio cada marca
df_ultimo_anio = df_marca_anio.groupBy("marca") \
    .agg(F.max("anio").alias("ultimo_anio"))

# Paso 4: detectar marcas que dejaron de aparecer
df_marcas_desaparecidas = df_ultimo_anio.filter(F.col("ultimo_anio") < max_anio) \
                                        .orderBy("ultimo_anio", "marca")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#IMPRESION
from itertools import groupby

# Recolectamos los resultados
rows = df_marcas_desaparecidas.collect()

# Agrupamos por último año de aparición
for anio, grupo in groupby(rows, key=lambda r: r['ultimo_anio']):
    print(f"\n\n{'='*50}")
    print(f"AÑO DE DESAPARICIÓN: {anio}")
    print(f"{'='*50}")
    print(f"{'Marca':<40}")
    print("-" * 40)
    for row in grupo:
        print(f"{row['marca']:<40}")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ==================================================
# A?O DE DESAPARICI?N: 2018
# ==================================================
# Marca
# ----------------------------------------
# alpino. pavino.
# big cola
# chalet
# d calidad chedraui
# kleen bebe. comodisec max
# lala. siluette plus 0%
# manzana lift
# morelos. independiente
# morelos. independiente o mexicano tradicional
# morelos. insurgente
# nochebuena
# osram. dulux el micro twist. 10 anos
# philips. mini twister. t2. 8 anos
# rosa blanca
# v8 splash
# vita real
# yemina
#
#
# ==================================================
# A?O DE DESAPARICI?N: 2019
# ==================================================
# Marca
# ----------------------------------------
# alfaparf. 4
# campo fresco
# carlos v. nestle
# crackets
# crest. complet
# el pomar
# freska-ra. 4d
# froot loops. kellogg s
# g.e. energy smart espiral 8000 horas
# iberia
# kellogg s
# labello
# nordiko
# palette. color creme. 4-0
# parmalat. entera
# parmalat. semi
# revlon. colorsilk. 40
# rosa venus
# san lazaro super extra
# schick
# snickers
# valle redondo
#
#
# ==================================================
# A?O DE DESAPARICI?N: 2020
# ==================================================
# Marca
# ----------------------------------------
# kleenex. cotonelle
# la gloria
# lys
# patrona
# regio. r3
#
#
# ==================================================
# A?O DE DESAPARICI?N: 2021
# ==================================================
# Marca
# ----------------------------------------
# aksi. 20 w. 10 anos
# chedraui. espiral sp-20w. 6 anos
# colgate. luminous white. instant
# el cerdito
# grano de oro
# kartamus
# l oreal. paris. casting. 400
# lysol. neutra air
# mundet lift
# nido. entera (fortigrow)
# nivea baby
# oral-b. 3d white
# oust
# quality day. espiral 8000 horas sp-23w-lf
# savile. hidratacion
# soriana. espiral. 8000 horas. modelo fases 20b
#
#
# ==================================================
# A?O DE DESAPARICI?N: 2022
# ==================================================
# Marca
# ----------------------------------------
# alpura. kids
# alpura. vaquitas
# aunt jemima
# bebin
# el yuka
# elite. color
# fitness nestle
# fortileche
# kleenex
# kleenex. cottonelle. soft care
# la lechera. sin grasa
# maceite
# maravilla
# mc cormick light
# natures heart
# nesquik nestle
# petalo. ultra care
# sello rojo. entera
# tuny. light
# viva. lavanda
#
#
# ==================================================
# A?O DE DESAPARICI?N: 2023
# ==================================================
# Marca
# ----------------------------------------
# alei
# baygon. total
# colgate. luminous white. instant.
# delsey. max
# dolce kristal
# elite. xl. softmax
# frutimax
# gamesa. select
# gran cosecha. premium
# hada
# lyncott
# oral-b. 3d white. medio 40
# osram. dulux el micro twist. 23w/830. 12 anos
# osram. dulux value el twist. 23w/827. 8 anos
# paisa
# quality day
# quality day. led a 19
# san diego
# svelty. con colageno. move+
# wands

# %% [markdown]
# ### Gráfica de serie de tiempo por estado para el par producto-marca con mayor precio promedio

# %% [markdown]
# #### 1.- Obtener el par producto-marca con mayor precio promedio por año y estado.

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# 1. Promedio de precios por estado, producto y marca
df_avg = df_basicos.groupBy("estado", "producto", "marca") \
    .agg(F.avg("precio").alias("precio_promedio"))

# 2. Ventana para obtener el top 1 por estado
window = Window.partitionBy("estado").orderBy(F.desc("precio_promedio"))

# 3. Top 1 por estado
df_top1 = df_avg.withColumn("rank", F.row_number().over(window)) \
                .filter(F.col("rank") == 1) \
                .select("estado", "producto", "marca")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# #### 2.- Obtener los precios máximos por año para ese par producto-marca en cada estado

# %%
# Unimos con el dataset original para filtrar solo esas combinaciones
df_filtrado = df_basicos.join(df_top1, on=["estado", "producto", "marca"], how="inner")

# Preparamos la serie de tiempo: precio máximo por año
df_serie = df_filtrado.groupBy("estado", "producto", "marca", "anio") \
    .agg(F.max("precio").alias("precio_maximo")) \
    .orderBy("estado", "anio")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %% [markdown]
# #### 3.- Guardamos como CSV en  el bucket para luego descargarlo de forma local.

# %%
df_serie.write.mode("overwrite").option("header", "true").csv(f"{BUCKET}/{FOLDER}/serie_estado_producto")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
